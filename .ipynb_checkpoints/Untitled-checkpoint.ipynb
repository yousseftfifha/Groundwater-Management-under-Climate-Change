# %% [markdown]
# Post ID: the key for this metric is “post_id“.<br>
# Text: they key for this metric is “text“.<br>
# Publication Time: the key for this metric is “time“.<br>
# Image: the key for this metric is “image” and it will return the link of the main image of the post.<br>
# Video: the key for this metric is “video” and it will return the link of the main image of the post.<br>
# Video Thumbnail: the key for this metric is “video_thumbnail“.<br>
# Video ID: the key for this metric is “video_id“.<br>
# Number of likes: the key for this metric is “likes”.<br>
# Number of comments: the key for this metric is “comments”.<br>
# Number of shares: the key for this metric is “shares”.<br>
# Post URL: the key for this metric is “post_url”.<br>
# Link: the key for this metric is “link”.<br>
# Images: if there are several images, this variable will store a list with all the images links. The key for this metric is “images”.<br>

# %%
from facebook_scraper import get_posts
 
listposts = []
for post in get_posts("OrangeTNplus", pages=2):
    print(post['text'])
    listposts.append(post)
# Out:
# 🚀 Accède sans attendre à notre formation #GRATUITE : https://bit.ly/3aKMajz
# une formation #Scrum, du 28 au 30 juillet, une occasion pour apprendre et comprendre les leviers 📊🏗 permettant de mettre en place une #gestion_de_projets souple et une démarche d'amélioration continue📈🎯
# 245 Likes18 comments
# Cyrine Louhichi
# Dorra Ben Jannet
# Orange Digital Center
# July 17 at 10:15 AM ·
# Pour les adultes de demain 🙋‍♀️🙋‍♂️ et la #tech du futur 🤖❗ Réservez une place 👉 : https://bit.ly/3OfLmRe #OrangeDigitalCenter #LaMarsa et Cody Space organisent un atelier de codage et robotique 💻🎮 avec #Scratch et #LEGO #WeDo 2.0, #GRATUIT, pour les enfants âgés de 7 à 11 ans.
# 716 Likes18 comments
# Sousou Ghada
# https://
# youtu.be/
# zzPDj7u3LrM
# Loading...
# Try Again
# Cancel
# Loading...
# Loading...
# ...

# %%
import pandas as pd
 
df = pd.DataFrame(listposts)

# %%
df
# Out:
#                                              post_id  \
# 0  pfbid02NtZ9ZqVwKopZwgPKZ9Su4YY5Htj1Zp528g17Liy...
# 1  pfbid02NtZ9ZqVwKopZwgPKZ9Su4YY5Htj1Zp528g17Liy...
# 2                                   5047109138749964
# 3                                   5047151435412401
# 4                                   5047059995421545
# 5                                   5047965965330948
#
#                                                 text  \
# 0  🚀 Accède sans attendre à notre formation #GRAT...
# 1  Pour les adultes de demain 🙋‍♀️🙋‍♂️ et la #tec...
# 2  Saisissez le #Power du futur 💪⚡ à travers la #...
# 3  Devenez de véritable #GameDesigners 🎮 et const...
# 4  Êtes-vous prêt à devenir #Big en #Bigdata ? Ré...
# 5  Apprenez à coder 💻 dans l'univers Minecraft 🎮📦...
#
#                                            post_text  \
# 0  🚀 Accède sans attendre à notre formation #GRAT...
# 1  Pour les adultes de demain 🙋‍♀️🙋‍♂️ et la #tec...
# ...

# %%
from scraper.scraper import FacebookScraper
# Out:
# Traceback (most recent call last):
#
#   File C:\Users\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3369 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Input In [24] in <cell line: 1>
#     from scraper.scraper import FacebookScraper
#
#   File C:\Users\anaconda3\lib\site-packages\scraper\scraper.py:49
#     print "Error decoding %s field: %s" % (field, e)
#           ^
# SyntaxError: invalid syntax

# %%
pip install scraper
# Out:
# ...
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
