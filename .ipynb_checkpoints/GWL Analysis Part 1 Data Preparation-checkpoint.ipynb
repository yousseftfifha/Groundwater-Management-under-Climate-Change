# %% [markdown]
# # <center>${\textbf{Artificial Intelligence Decision Support System}}$<br>${\textbf{ for Groundwater Management under Climate Change:}}$</center><br><center>${\textbf{ Application to Mornag Region in Tunisia}}$</center><br><center>${\textbf{ Part 1 : Data Preparation}}$</center>

# %% [markdown]
# **Table of Contents**
#
# * [Overview](#overview)
# * [Importing Libraries](#libraris)
# * [Loading Data](#loading)
#     * [Loading Piezometric Data](#load_piezo)
#     * [Loading Rainfall Data](#load_rain)
#     * [Loading zones Data](#load_zone)
#     * [Loading RCP 4.5 Data](#load_rcp4.5)
#     * [Loading RCP 8.5 Data](#load_rcp8.5)
# * [Data Preparation](#data_prep)
#     * [Pluvometric data preprocessing](#rain_pp)
#     * [Piezometric data preprocessing](#piezo_pp)
#     * [Historical data preprocessing](#data_pp)
#     * [Representative Concentration Pathway :RCP 8.5 Preparation](#rcp45_pp)
#     * [Representative Concentration Pathway :RCP 8.5 Preparation](#rcp85_pp)

# %% [markdown]
# <a id="overview"></a>
# ${\textbf{Overview}}$

# %% [markdown]
# This project aims to study  the impact of climate change on groundwater level in Mornag plain in Tunisia. Indeed, in the last few decades, aquifers all over the world have experienced notable water level variability due to the spatiotemporal variability of rainfall and temperature. Therefore, for a reliable groundwater management under climate change context, it is mandatory to analyze and estimate its level variability. In this study, we focus on the plain of Mornag, located in the southeast of Tunisia, since it represents 33% of the national agricultural production. From this plain, we have collected historical piezometric and pluviometric data covering the period 2005-2017. Knowing the pluviometric data, our goal is to predict the piezometric one. This  issue has been already studied using classical numerical groundwater modeling such as Modflow and Feflow. Despite unsatisfactory results,  these techniques are data and time consuming. To overcome all these drawbacks, we propose to use two Artificial Intelligence (AI) approaches: the Extreme Gradient Boosting (XGBoost) approach, that has shown great performances in literature,  and the well used one in our context which involves the use of Long-Short Term Memory (LSTM) Neural Network. For better results, we have added supplementary features to our dataset such as the cluster zone (zones with same characteristics) and the Standardized Precipitation Index (SPI) which can identify drought at different time scales.  Both approaches have been executed entirely on GPU for time acceleration. Compared with traditional existing methods, they both have shown a high level of accuracy which confirms their adequacy for groundwater level  forecasting. The proposed  prediction models will be used for evaluating the repercussions of climate change on groundwater levels under the different scenarios RCP 4.5 and RCP 8.5 for the period of 2017-2090.  It will be evaluated for three future periods: 2017-2040 (short term), 2041-2065 (medium term) and 2066-2090 (long term). The analysis of the future results using AI will be considered as a new Decision Support System used to optimize the management of our limited resources in order to satisfy the needs of the population in terms of drinking water and agriculture production.

# %% [markdown]
# <a id="libraries"></a>
#
# ${\textbf{Importing Libraries}}$

# %%
# %matplotlib inline
import warnings
warnings.simplefilter("ignore")

import numpy as np
import pandas as pd

import datetime 

import time
import utm

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error


import statsmodels.api as sm

# %% [markdown]
# <a id="load_piezo"></a>
# ${\textbf{Loading Piezometric data}}$

# %%
data_piezo = pd.read_excel("./Data/données_piezo.xlsx")#Read XLSX file

# %% [markdown]
# <a id="load_rain"></a>
#
# ${\textbf{Loading Pluviometric data}}$

# %%
data_rain = pd.read_excel("./Data/donnée_pluviolétrique.xlsx")#Read XLSX file

# %% [markdown]
# <a id="load_zone"></a>
#
# ${\textbf{Loading Zones data}}$

# %%
data_piezo_zone = pd.read_excel("./Data/les zones.xlsx",sheet_name='piézo+zone')##Read XLSX file-first sheet
data_rain_zone = pd.read_excel("./Data/les zones.xlsx",sheet_name='pluvio+zone')##Read XLSX file-second sheet

# %% [markdown]
# <a id="load_rcp4.5"></a>
# ${\textbf{Loading RCP 4.5 data}}$

# %%
RCP45 = pd.read_excel("./Data/RCP4.5.monthly_totals.xlsx")#Read XLSX file

# %% [markdown]
# <a id="load_rcp8.5"></a>
# ${\textbf{Loading RCP 8.5 data}}$

# %%
RCP85 = pd.read_excel("./Data/RCP8.5.monthly_totals.xlsx")#Read XLSX file

# %% [markdown]
# <a id="rain_pp"></a>
#
# ${\textbf{Rainfall data Preparation}}$

# %%
data_rain.drop([0,1,2,3,4,5,6,7],0,inplace=True)#Eliminating the first rows which doesn't contain data
data_rain.rename(columns = {'Nom':'Date'}, inplace = True)#Renaming a column from "Nom" to Date

# %%
a = []#Dictionary
for j in range(0,len(data_rain)):
    for i in range(1,len(data_rain.columns)):
        a.append(
        {
            'Pluviometer':data_rain.columns[i],#Rain Gauge
            'Time':data_rain.iloc[j,0],#Time
            'RF':  data_rain.iloc[j,i]#RainFall
        }
    )
data_rain=pd.DataFrame(a)#Create a dataframe from the dict

# %%
data_rain_zone.rename(columns = {'Nom':'Pluviometer'}, inplace = True)#Renaming Zone_num to zone for more clarity
data_rain = pd.merge(data_rain,data_rain_zone, on='Pluviometer', how='inner')#Merging the zone with the pluviometric data on Rain Gauge
data_rain.rename(columns = {'Zone_num':'Zone'}, inplace = True)#Renaming Zone_num to zone for more clarity
data_rain.drop(columns=['X_carthage','Y_carthage','zone_name',],axis=1,inplace=True)#Droping the unuseful columns

# %%
data_rain['sem']= data_rain.Time.dt.year.astype(str) + 'S'+ np.where(data_rain.Time.dt.quarter.gt(2),2,1).astype(str)
#sem will contain for each row "based on the month and the year" which semester it belongs

# %%
data_rain['trim']= data_rain.Time.dt.year.astype(str) + 'T'+ data_rain.Time.dt.quarter.astype(str)
#trim will contain for each row "based on the month and the year" which trim it belongs

# %%
data_rain['year']= data_rain.Time.dt.year.astype(str) 
#trim will contain for each row "based on the month and the year" which trim it belongs

# %%
data_rain['month']=data_rain.Time.dt.year.astype(str) + 'M'+ data_rain.Time.dt.month.astype(str)

# %%
for i in range(0,len(data_rain)):
    data_rain.iloc[i,1]=data_rain.iloc[i,1].strftime("%d-%m-%Y")#Reformating the data from "%d/%m/%Y %h:%m:%s" to "%d-%m-%Y"

# %%
for i in data_rain.columns[data_rain.isnull().any(axis=0)]:     #---Applying Only on variables with NaN values
    data_rain[i].fillna(data_rain[i].mean(),inplace=True)# Fill NaN with the mean
data_rain.isnull().sum() / len(data_rain) * 100 #Percentage of NaN data
# Out:
# Pluviometer    0.0
# Time           0.0
# RF             0.0
# Latitude       0.0
# Longitude      0.0
# Zone           0.0
# sem            0.0
# trim           0.0
# year           0.0
# month          0.0
# dtype: float64

# %% [markdown]
# <a id="spi"></a>
#
# >${\textbf{Standardized Precipitation Index (SPI)}}$

# %% [markdown]
# Studying the  SPI  distinguishes  dry  and wet  years  the  deficit  years  of surplus  years.  A  drought conditions  when  the  SPI  is  consecutively  negative  and  its  value  reaches  -1  or  less  intensity  and  ends when  the  SPI  becomes  positive.  The  classes  of  SPI  index  is  subdivided  into  moderate and extreme classes for both dry and wet SPI

# %% [markdown]
# $$ SPI = {P_{i} - P_{m} \over S} $$
# Where <br>
# $P_{i}$ : the Daily rainfall of the day i,<br>
# $P_{m}$ : the Average rainfall  of  the  series  on the timescale  considered ,<br> and
# $S$ :Standard deviation  of  the  series  on the timescale considered.
# $\;$
# $\;$

# %% [markdown]
# | SPI | classes Degree of wet and drought |
# | :---: | :---: |
# |SPI>2 |Extremely wet |
# |1<SPI< 2 |Very wet |
# |0<SPI< 1 | Moderately wet|
# |-1<SPI< 0 |Moderately dry|
# |-2<SPI<-1 |Severely dry |
# |SPI< -2 |Extremely dry |

# %%
SPI=(data_rain['RF']-data_rain['RF'].mean())/data_rain['RF'].std()#SPI Calculation 
data_rain['SPI']=SPI#Creating a new column for the SPI

# %%
data_rain['SPI_classes']=""#Creating a new column for the interpretation of the spi
for i in range(0,len(data_rain)):
    if(data_rain['SPI'].values[i]>2):#SPI>2
        data_rain['SPI_classes'].values[i]="Extremely wet"
    elif((data_rain['SPI'].values[i]< 2) & (data_rain['SPI'].values[i] >1)):#1<SPI< 2
        data_rain['SPI_classes'].values[i]="Very wet"
    elif((data_rain['SPI'].values[i]< 1) & (data_rain['SPI'].values[i] >0)):#0<SPI< 1
        data_rain['SPI_classes'].values[i]="Moderately Wet"
    elif((data_rain['SPI'].values[i] >-1 )&( data_rain['SPI'].values[i] <0)):#-1<SPI< 0
        data_rain['SPI_classes'].values[i]="Moderately dry"
    elif((data_rain['SPI'].values[i] >-2 )&( data_rain['SPI'].values[i] <-1)):#-2<SPI<-1
        data_rain['SPI_classes'].values[i]="Severely dry"
    else :#SPI< -2
        data_rain['SPI_classes'].values[i]="Extremely dry"

# %%
dfSem=data_rain.copy()
dfSem=dfSem.groupby(['sem','Pluviometer']).sum('RF')#Summing Rainfall on Pluviometer and Semester
dfSem.drop(columns=['Zone','SPI','SPI','Latitude','Longitude'],axis=1,inplace=True)#Droping the unuseful columns
dfSem.rename(columns = {'RF':'SemestrialRF'}, inplace = True)#Renaming P to MonthlyP for more clarity

# %%
dfTrim=data_rain.copy()
dfTrim=dfTrim.groupby(['trim','Pluviometer']).sum('RF')#Summing Rainfall on Pluviometer and Trimestre
dfTrim.drop(columns=['Zone','SPI','SPI','Latitude','Longitude'],axis=1,inplace=True)#Droping the unuseful columns
dfTrim.rename(columns = {'RF':'TrimestrialRF'}, inplace = True)#Renaming RF to TrimestrialRF for more clarity

# %%
dfyear=data_rain.copy()
dfyear=dfyear.groupby(['year','Pluviometer']).sum('RF')#Summing Rainfall on Pluviometer and Trimestre
dfyear.drop(columns=['Zone','SPI','SPI','Latitude','Longitude'],axis=1,inplace=True)#Droping the unuseful columns
dfyear.rename(columns = {'RF':'YearlyRF'}, inplace = True)#Renaming RF to TrimestrialRF for more clarity

# %%
dfmonthly=data_rain.copy()
dfmonthly=dfmonthly.groupby(['month','Pluviometer']).sum('RF')#Summing Rainfall on Pluviometer and Trimestre
dfmonthly.drop(columns=['Zone','SPI','SPI','Latitude','Longitude'],axis=1,inplace=True)#Droping the unuseful columns
dfmonthly.rename(columns = {'RF':'MonthlyRF'}, inplace = True)#Renaming RF to TrimestrialRF for more clarity

# %%
data_rain = pd.merge(data_rain,dfyear, on=['year','Pluviometer'], how='inner')#Merging the zone with the pluviometric data on Rain Gauge
data_rain = pd.merge(data_rain,dfSem, on=['sem','Pluviometer'], how='inner')#Merging the zone with the pluviometric data on Rain Gauge
data_rain = pd.merge(data_rain,dfTrim, on=['trim','Pluviometer'], how='inner')#Merging the zone with the pluviometric data on Rain Gauge
data_rain = pd.merge(data_rain,dfmonthly, on=['month','Pluviometer'], how='inner')#Merging the zone with the pluviometric data on Rain Gauge

data_rain.rename(columns = {'Latitude':'Lat_Pluviometer','Longitude':'Lon_Pluviometer'}, inplace = True)#Renaming P to MonthlyP for more clarity
column=['Time','Pluviometer','Lat_Pluviometer','Lon_Pluviometer','sem','trim','Zone','SPI','SPI_classes','RF','YearlyRF','SemestrialRF','TrimestrialRF','MonthlyRF']#Reindexing
data_rain=data_rain.reindex(column, axis='columns')

# %%
data_rain#show dataframe
# Out:
#             Time           Pluviometer  Lat_Pluviometer  Lon_Pluviometer  \
# 0     2005-01-09  BEN AROUS I MUNICIPA         36.76500        -10.22111
# 1     2005-02-09  BEN AROUS I MUNICIPA         36.76500        -10.22111
# 2     2005-03-09  BEN AROUS I MUNICIPA         36.76500        -10.22111
# 3     2005-04-09  BEN AROUS I MUNICIPA         36.76500        -10.22111
# 4     2005-05-09  BEN AROUS I MUNICIPA         36.76500        -10.22111
# ...          ...                   ...              ...              ...
# 65731 2015-08-27              RADES PF         36.75222        -10.26361
# 65732 2015-08-28              RADES PF         36.75222        -10.26361
# 65733 2015-08-29              RADES PF         36.75222        -10.26361
# 65734 2015-08-30              RADES PF         36.75222        -10.26361
# 65735 2015-08-31              RADES PF         36.75222        -10.26361
#
#           sem    trim  Zone       SPI     SPI_classes   RF  YearlyRF  \
# 0      2005S2  2005T3     4 -0.236898  Moderately dry  0.0     212.7
# 1      2005S2  2005T3     4 -0.236898  Moderately dry  0.0     212.7
# 2      2005S2  2005T3     4 -0.236898  Moderately dry  0.0     212.7
# 3      2005S2  2005T3     4 -0.236898  Moderately dry  0.0     212.7
# 4      2005S2  2005T3     4 -0.236898  Moderately dry  0.0     212.7
# ...       ...     ...   ...       ...             ...  ...       ...
# 65731  2015S2  2015T3     4 -0.236898  Moderately dry  0.0     304.5
# 65732  2015S2  2015T3     4 -0.236898  Moderately dry  0.0     304.5
# 65733  2015S2  2015T3     4 -0.236898  Moderately dry  0.0     304.5
# 65734  2015S2  2015T3     4 -0.236898  Moderately dry  0.0     304.5
# 65735  2015S2  2015T3     4 -0.236898  Moderately dry  0.0     304.5
#
#        SemestrialRF  TrimestrialRF  MonthlyRF
# 0             212.7           23.6       23.6
# 1             212.7           23.6       23.6
# 2             212.7           23.6       23.6
# 3             212.7           23.6       23.6
# 4             212.7           23.6       23.6
# ...             ...            ...        ...
# 65731          40.0           40.0       40.0
# 65732          40.0           40.0       40.0
# 65733          40.0           40.0       40.0
# 65734          40.0           40.0       40.0
# 65735          40.0           40.0       40.0
#
# [65736 rows x 14 columns]

# %%
data_rain.to_pickle("./Pickles/Data/Rainfall_Data.pkl")

# %% [markdown]
# <a id="piezo_pp"></a>
#
# ${\textbf{Piezometric data Preparation}}$

# %%
data_piezo.drop(data_piezo.iloc[:, 9:78], inplace = True, axis = 1)#Impute data from 1971 to 2004

# %%
for i in data_piezo.columns[data_piezo.isnull().any(axis=0)]:     #---Applying Only on variables with NaN values
    data_piezo[i].fillna(data_piezo[i].mean(),inplace=True)#Fill NaN value by mean

# %%
def convert(date_time):
    '''
    Convert String to Date
    
    Args:
        date_time (String) 
    
    Returns:
        DateTime
    ''' 
    datetime_str = datetime.datetime.strptime(date_time, '%b,%Y')    
    return datetime_str

# %% [markdown]
# >>${\textbf{Piezometric Level (Pz)}}$

# %% [markdown]
# <img src="./Images/Pz.jpg" width="800" height="400">
# $$ Pz = {TN + M - SL} $$
# Where <br>
# $TN$ : TN,<br>
# $M$ : Margelle ,<br> and
# $SL$ : Static level.
# $\;$
# $\;$

# %%
column_headers = list(data_piezo.columns)#Columns originally are the wells and piezometric stations
for i in range(9,len(column_headers)):
    if data_piezo[column_headers[i]] is None:
        data_piezo[column_headers[i]] = 0.0
    else:
        data_piezo[column_headers[i]]=data_piezo['TN+M'].astype(float)-data_piezo[column_headers[i]].astype(float)#TN+M-SL
    column_headers[i] = convert(column_headers[i])#Call convert function

data_piezo.columns=column_headers

# %%
data_piezo.rename(columns = {'X_UTM_Carthage32N':'Lat','Y_UTM_Carthage32N':'Lon'}, inplace = True)#Renaming UTM columns
latlon=utm.to_latlon(data_piezo['Lat'],data_piezo['Lon'],zone_number=32,zone_letter='n')#Converting from UTM 32 N to latitude and Longitude
#Latlon is a tuple
data_piezo['Lat']=latlon[0]#Lat
data_piezo['Lon']=latlon[1]#Lon

# %%
data_piezo_zone.rename(columns = {'NOM':'Nom'}, inplace = True)#Renaming NOM to Nom for the sake of merging later on
data_piezo.drop(columns=['NUM_IRH','TYPE','MNT','TN','margelle','TN+M',],axis=1,inplace=True)#Droping unuseful columns 
data_piezo_zone.drop(columns=['NUM_IRH','X_UTM_Cart','Y_UTM_Cart','zone_name'],axis=1,inplace=True)#Droping unuseful columns

# %%
d = []#Dictionary
for j in range(0,len(data_piezo)):
    for i in range(3,len(data_piezo.columns)):
        d.append(
        {
            'Piezometer': data_piezo.iloc[j,0],#Piezometer/Well/Station
            'Time':data_piezo.columns[i],#Time
            'Lat':data_piezo.iloc[j,1],#Latitude
            'Lon':data_piezo.iloc[j,2],#Longitude
            'Pz':  data_piezo.iloc[j,i]#Piezometric level
        }
    )
data_piezo=pd.DataFrame(d)#Create a dataframe from the dict

# %%
data_piezo_zone.rename(columns = {'Nom':'Piezometer'}, inplace = True)#Renaming Zone_num to Zone for a better reading
data_piezo = pd.merge(data_piezo,data_piezo_zone, on='Piezometer', how='inner')#Merging piezometric level with its zones
data_piezo.rename(columns = {'Zone_num':'Zone'}, inplace = True)#Renaming Zone_num to Zone for a better reading

# %%
data_piezo['sem']= data_piezo.Time.dt.year.astype(str) + 'S'+ np.where(data_piezo.Time.dt.quarter.gt(2),2,1).astype(str)
#Just like for the pluviometric data sem will contain for each row "based on the month and the year" which semester it belongs

# %%
data_piezo['trim']= data_piezo.Time.dt.year.astype(str) + 'T'+ data_piezo.Time.dt.quarter.astype(str)
#trim will contain for each row "based on the month and the year" which trim it belongs

# %%
if(pd.isna(data_piezo['Pz'][0])):#First column is NaN
    data_piezo['Pz'][0]=(data_piezo['Pz'][i+1]+data_piezo['Pz'][i+2])/2
for i in range(0,len(data_piezo)):
    if(pd.isna(data_piezo['Pz'][i])):#Other columns are NaN
        data_piezo['Pz'][i]=(data_piezo['Pz'][i+1]+data_piezo['Pz'][i-1])/2 
data_piezo.isnull().sum() / len(data_piezo) * 100#Checking NaN percentage
# Out:
# Piezometer    0.0
# Time          0.0
# Lat           0.0
# Lon           0.0
# Pz            0.0
# Zone          0.0
# sem           0.0
# trim          0.0
# dtype: float64

# %%
data_piezo#Show Piezometric data
# Out:
#            Piezometer       Time        Lat        Lon         Pz  Zone  \
# 0      Puits Barrouta 2005-09-01  36.620943  10.179025  53.433000     1
# 1      Puits Barrouta 2006-04-01  36.620943  10.179025  53.533000     1
# 2      Puits Barrouta 2006-09-01  36.620943  10.179025  53.413000     1
# 3      Puits Barrouta 2007-04-01  36.620943  10.179025  53.573000     1
# 4      Puits Barrouta 2007-09-01  36.620943  10.179025  53.373000     1
# ...               ...        ...        ...        ...        ...   ...
# 1095  UCP Errissala_B 2015-09-01  36.657951  10.324284  44.770923     2
# 1096  UCP Errissala_B 2016-04-01  36.657951  10.324284  43.680923     2
# 1097  UCP Errissala_B 2016-09-01  36.657951  10.324284  44.156308     2
# 1098  UCP Errissala_B 2017-04-01  36.657951  10.324284  45.884833     2
# 1099  UCP Errissala_B 2017-09-01  36.657951  10.324284  44.651500     2
#
#          sem    trim
# 0     2005S2  2005T3
# 1     2006S1  2006T2
# 2     2006S2  2006T3
# 3     2007S1  2007T2
# 4     2007S2  2007T3
# ...      ...     ...
# 1095  2015S2  2015T3
# 1096  2016S1  2016T2
# 1097  2016S2  2016T3
# 1098  2017S1  2017T2
# 1099  2017S2  2017T3
#
# [1100 rows x 8 columns]

# %%
data_piezo.to_pickle("./Pickles/Data/Piezometric_Data.pkl")

# %%
dataMap=data_piezo[['Piezometer','Lat','Lon']].copy()
dataMap.un

# %% [markdown]
# <a id="data_pp"></a>
#
# ${\textbf{Historical data preprocessing}}$

# %%
data= pd.merge(data_piezo,data_rain, on=['sem','trim','Zone'], how='inner')#Merging piezometric data and pluviometric data on sem and zone
data.rename(columns = {'Time_x':'Time_PZ','Time_y':'Time_RF','sem':'Semester'}, inplace = True)#Renaming certain columns

# %%
# del data['Time_PZ']#Time_Pz is no useful any longer
column=['Time_PZ','Piezometer','Pz','Time_RF','Pluviometer','RF','YearlyRF','SemestrialRF','TrimestrialRF','MonthlyRF','Zone','SPI','SPI_classes','Lat','Lon','Lat_Pluviometer','Lon_Pluviometer']#Reindexing
data=data.reindex(column, axis='columns')

# %%
data.sample(n=10)#Random sample of the data
# Out:
#           Time_PZ         Piezometer         Pz    Time_RF  \
# 113784 2011-04-01               Fraj  10.690000 2011-06-15
# 218081 2013-09-01        B. Abdallah   5.932692 2013-03-08
# 254005 2009-09-01              Mzabi  52.856000 2009-09-24
# 96717  2008-09-01             Majoul  -9.990952 2008-07-28
# 64587  2014-09-01    Ecole de Police  14.476250 2014-09-22
# 233356 2015-09-01           Puit OTD  15.784923 2015-08-16
# 209414 2012-09-01    Huritier Sgaier   2.205000 2012-08-30
# 71507  2015-09-01    Ecole de Police  14.026923 2015-08-13
# 154054 2006-04-01  UCP Errissala_620  25.520000 2006-06-06
# 88417  2007-09-01           El Attar -11.030952 2007-08-27
#
#                  Pluviometer   RF    YearlyRF  SemestrialRF  TrimestrialRF  \
# 113784               EZZAHRA  0.0  594.999998    263.200000      94.200001
# 218081  FOUCHANA FERME GAMOU  0.0  439.600000    213.100000      93.600000
# 254005     MORNAG SIDI ZEYED  0.0  715.300000    219.600000     120.100000
# 96717            RADES OUAFA  0.0  139.800001     55.500001       0.000000
# 64587   MHAMEDIA DISPENSAIRE  0.0  285.500000     95.700000       2.000000
# 233356  MORNEG FERME ESSADIR  0.0  245.700000     42.000000      42.000000
# 209414  MORNEG FERME ESSADIR  0.0  435.200000    230.700000      49.000000
# 71507   MHAMEDIA DISPENSAIRE  0.0  262.500000     41.500000      41.500000
# 154054  FOUCHANA FERME GAMOU  0.0  586.400000    323.700000      71.600000
# 88417            RADES OUAFA  0.0  488.400001    299.799999      67.500000
#
#         MonthlyRF  Zone       SPI     SPI_classes        Lat        Lon  \
# 113784       17.6     4 -0.236898  Moderately dry  36.721854  10.300582
# 218081       26.5     3 -0.236898  Moderately dry  36.672278  10.257671
# 254005       62.1     2 -0.236898  Moderately dry  36.658741  10.325450
# 96717         0.0     4 -0.236898  Moderately dry  36.736674  10.273134
# 64587         2.0     1 -0.236898  Moderately dry  36.643825  10.253364
# 233356       42.0     3 -0.236898  Moderately dry  36.659020  10.290883
# 209414        0.0     3 -0.236898  Moderately dry  36.712059  10.263688
# 71507        41.5     1 -0.236898  Moderately dry  36.643825  10.253364
# 154054        4.4     3 -0.236898  Moderately dry  36.667605  10.306164
# 88417         0.0     4 -0.236898  Moderately dry  36.728039  10.314714
#
#         Lat_Pluviometer  Lon_Pluviometer
# 113784         36.75583        -10.31111
# 218081         36.69056        -10.18028
# 254005         36.63111        -10.28250
# 96717          36.76500        -10.28417
# 64587          36.63694        -10.15917
# 233356         36.66806        -10.27917
# 209414         36.66806        -10.27917
# 71507          36.63694        -10.15917
# 154054         36.69056        -10.18028
# 88417          36.76500        -10.28417

# %%
data.shape
# Out:
# (285480, 17)

# %%
data.to_pickle("./Pickles/Data/Historical_Data.pkl")

# %% [markdown]
# <a id="rcp45_pp"></a>
#
# ${\textbf{Representative Concentration Pathway :RCP 4.5 Preparation}}$

# %%
RCP45.rename(columns = {'date(YYYY-MM)':'date'}, inplace = True)
list_Year= [d.year for d in RCP45.date]
list_Month= [d.month for d in RCP45.date]
RCP45['Month'] = list_Month
RCP45['Year'] = list_Year

# %%
for i in RCP45.columns[RCP45.isnull().any(axis=0)]:     #---Applying Only on variables with NaN values
    RCP45[i].fillna(RCP45[i].mean(),inplace=True)#Fill NaN value by mean

# %%
RCP45Crossed=RCP45[(RCP45.Year>=2009) & (RCP45.Year<=2015)]

# %%
df=data_rain.copy()
list_Year= [d.year for d in df.Time]
list_Month= [d.month for d in df.Time]
df['Month'] = list_Month
df['Year'] = list_Year
dfCrossed=df[(df.Year>=2009) & (df.Year<=2015)]
df=dfCrossed[['Pluviometer', 'MonthlyRF', 'Year', 'Month']].copy()

# %%
rg=df['Pluviometer'].unique()
storage=list()
for i in range(0,len(rg)):
    aa=df[["MonthlyRF","Year",'Month']][(df.Pluviometer==rg[i])].groupby(["Year",'Month']).mean()
    aa.rename(columns = {'MonthlyRF':rg[i]}, inplace = True)#Renaming certain columns
    storage.append(aa)

# %%
for i in range(0,len(storage)):
    RCP45Crossed= pd.merge(RCP45Crossed,storage[i], on=['Year','Month'], how='inner')#Merging piezometric data and pluviometric data on sem and zone

# %%
RCP45Crossed.index=RCP45Crossed.date
del RCP45Crossed['date']

# %%
storageLR=list()
for i in range(13,len(RCP45Crossed.columns)):
    X = RCP45Crossed[['MIROC-ESM', 'CNRM-CM5', 'CanESM2', 'FGOALS-s2', 'BNU-ESM',
       'MIROC5', 'GFDL-ESM2G', 'MIROC-ESM-CHEM', 'GFDL-ESM2M', 'MRI-CGCM3',
       'MRI-CGCM3.1']].copy()
#     X = sm.add_constant(X)
    y = RCP45Crossed[[RCP45Crossed.columns[i]]]
    X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.3, random_state=23)
    est1 = sm.OLS(y_train, X_train)
    est2 = est1.fit()
    y_pred=est2.predict(X_test)
    print(RCP45Crossed.columns[i])
    print("\n")
    print(est2.summary())
    print("\n")
    RMSE=np.sqrt(mean_squared_error(y_test,y_pred))
    storageLR.append(
            {
                'RG':RCP45Crossed.columns[i],
                'RMSE':  RMSE,
                'Adj. R-squared':est2.rsquared_adj,
                'AIC':est2.aic,
                'BIC':est2.bic,
                'est':est2
            }
        )
rmseDataLR=pd.DataFrame(storageLR)
# Out:
# BEN AROUS I MUNICIPA
#
#
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     BEN AROUS I MUNICIPA   R-squared (uncentered):                   0.730
# Model:                              OLS   Adj. R-squared (uncentered):              0.674
# Method:                   Least Squares   F-statistic:                              13.01
# Date:                  Fri, 22 Jul 2022   Prob (F-statistic):                    1.34e-10
# Time:                          11:11:21   Log-Likelihood:                         -267.28
# No. Observations:                    58   AIC:                                      554.6
# Df Residuals:                        48   BIC:                                      575.2
# Df Model:                            10
# Covariance Type:              nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.4218      0.165      2.562      0.014       0.091       0.753
# CNRM-CM5          -0.0240      0.144     -0.166      0.869      -0.314       0.266
# CanESM2            0.1368      0.171      0.799      0.428      -0.207       0.481
# FGOALS-s2         -0.1092      0.167     -0.654      0.516      -0.445       0.227
# BNU-ESM            0.2710      0.233      1.165      0.250      -0.197       0.738
# MIROC5             0.1782      0.194      0.919      0.363      -0.212       0.568
# GFDL-ESM2G        -0.2341      0.160     -1.465      0.149      -0.555       0.087
# MIROC-ESM-CHEM     0.0537      0.173      0.311      0.757      -0.294       0.401
# GFDL-ESM2M         0.1577      0.129      1.218      0.229      -0.103       0.418
# MRI-CGCM3          0.0945      0.079      1.195      0.238      -0.064       0.253
# MRI-CGCM3.1        0.0945      0.079      1.195      0.238      -0.064       0.253
# ==============================================================================
# Omnibus:                       29.028   Durbin-Watson:                   2.320
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               69.813
# Skew:                           1.470   Prob(JB):                     6.92e-16
# Kurtosis:                       7.499   Cond. No.                     2.99e+16
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is 1.2e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
# BOUMHEL BASSATINE MU
#
#
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     BOUMHEL BASSATINE MU   R-squared (uncentered):                   0.648
# Model:                              OLS   Adj. R-squared (uncentered):              0.575
# Method:                   Least Squares   F-statistic:                              8.847
# Date:                  Fri, 22 Jul 2022   Prob (F-statistic):                    5.08e-08
# Time:                          11:11:21   Log-Likelihood:                         -272.90
# No. Observations:                    58   AIC:                                      565.8
# Df Residuals:                        48   BIC:                                      586.4
# Df Model:                            10
# Covariance Type:              nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.3483      0.181      1.920      0.061      -0.016       0.713
# CNRM-CM5           0.0080      0.159      0.051      0.960      -0.311       0.328
# CanESM2            0.1819      0.189      0.965      0.339      -0.197       0.561
# FGOALS-s2         -0.1723      0.184     -0.937      0.354      -0.542       0.198
# BNU-ESM            0.4485      0.256      1.751      0.086      -0.067       0.964
# MIROC5             0.1281      0.214      0.600      0.551      -0.301       0.558
# GFDL-ESM2G        -0.2605      0.176     -1.480      0.145      -0.614       0.093
# MIROC-ESM-CHEM     0.0837      0.190      0.440      0.662      -0.299       0.466
# GFDL-ESM2M         0.1307      0.143      0.916      0.364      -0.156       0.417
# MRI-CGCM3          0.0307      0.087      0.352      0.726      -0.144       0.206
# MRI-CGCM3.1        0.0307      0.087      0.352      0.726      -0.144       0.206
# ==============================================================================
# Omnibus:                       51.632   Durbin-Watson:                   2.180
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              283.040
# Skew:                           2.371   Prob(JB):                     3.46e-62
# Kurtosis:                      12.728   Cond. No.                     2.99e+16
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is 1.2e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
# CRETEVILLE
#
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             CRETEVILLE   R-squared (uncentered):                   0.681
# Model:                            OLS   Adj. R-squared (uncentered):              0.614
# Method:                 Least Squares   F-statistic:                              10.23
# Date:                Fri, 22 Jul 2022   Prob (F-statistic):                    5.99e-09
# Time:                        11:11:21   Log-Likelihood:                         -282.21
# No. Observations:                  58   AIC:                                      584.4
# Df Residuals:                      48   BIC:                                      605.0
# Df Model:                          10
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.5971      0.213      2.804      0.007       0.169       1.025
# CNRM-CM5           0.0125      0.187      0.067      0.947      -0.363       0.388
# CanESM2            0.1418      0.221      0.641      0.525      -0.303       0.587
# FGOALS-s2         -0.2436      0.216     -1.128      0.265      -0.678       0.191
# BNU-ESM            0.4575      0.301      1.521      0.135      -0.147       1.062
# MIROC5             0.2546      0.251      1.015      0.315      -0.250       0.759
# GFDL-ESM2G        -0.3869      0.207     -1.872      0.067      -0.802       0.029
# MIROC-ESM-CHEM     0.1157      0.224      0.518      0.607      -0.334       0.565
# GFDL-ESM2M         0.1018      0.167      0.608      0.546      -0.235       0.438
# MRI-CGCM3          0.0801      0.102      0.783      0.437      -0.126       0.286
# MRI-CGCM3.1        0.0801      0.102      0.783      0.437      -0.126       0.286
# ==============================================================================
# Omnibus:                       46.636   Durbin-Watson:                   2.339
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              190.041
# Skew:                           2.239   Prob(JB):                     5.41e-42
# Kurtosis:                      10.654   Cond. No.                     2.99e+16
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is 1.2e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
# DOMAINE DECHAMUNE
#
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:      DOMAINE DECHAMUNE   R-squared (uncentered):                   0.694
# Model:                            OLS   Adj. R-squared (uncentered):              0.631
# Method:                 Least Squares   F-statistic:                              10.90
# Date:                Fri, 22 Jul 2022   Prob (F-statistic):                    2.28e-09
# Time:                        11:11:21   Log-Likelihood:                         -274.10
# No. Observations:                  58   AIC:                                      568.2
# Df Residuals:                      48   BIC:                                      588.8
# Df Model:                          10
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.3891      0.185      2.101      0.041       0.017       0.761
# CNRM-CM5           0.0219      0.162      0.135      0.893      -0.304       0.348
# CanESM2            0.1699      0.192      0.883      0.382      -0.217       0.557
# FGOALS-s2         -0.1820      0.188     -0.969      0.337      -0.560       0.196
# BNU-ESM            0.4201      0.262      1.606      0.115      -0.106       0.946
# MIROC5             0.2173      0.218      0.997      0.324      -0.221       0.656
# GFDL-ESM2G        -0.3351      0.180     -1.865      0.068      -0.697       0.026
# MIROC-ESM-CHEM     0.0957      0.194      0.492      0.625      -0.295       0.487
# GFDL-ESM2M         0.1317      0.146      0.905      0.370      -0.161       0.425
# MRI-CGCM3          0.0746      0.089      0.839      0.406      -0.104       0.253
# MRI-CGCM3.1        0.0746      0.089      0.839      0.406      -0.104       0.253
# ==============================================================================
# Omnibus:                       42.616   Durbin-Watson:                   2.180
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              171.177
# Skew:                           1.989   Prob(JB):                     6.75e-38
# Kurtosis:                      10.417   Cond. No.                     2.99e+16
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is 1.2e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
# EZZAHRA
#
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                EZZAHRA   R-squared (uncentered):                   0.614
# Model:                            OLS   Adj. R-squared (uncentered):              0.534
# Method:                 Least Squares   F-statistic:                              7.646
# Date:                Fri, 22 Jul 2022   Prob (F-statistic):                    3.79e-07
# Time:                        11:11:21   Log-Likelihood:                         -272.25
# No. Observations:                  58   AIC:                                      564.5
# Df Residuals:                      48   BIC:                                      585.1
# Df Model:                          10
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.1203      0.179      0.671      0.506      -0.240       0.481
# CNRM-CM5           0.0360      0.157      0.229      0.820      -0.280       0.352
# CanESM2            0.1012      0.186      0.543      0.590      -0.274       0.476
# FGOALS-s2         -0.1306      0.182     -0.718      0.476      -0.496       0.235
# BNU-ESM            0.4776      0.253      1.885      0.065      -0.032       0.987
# MIROC5             0.1757      0.211      0.832      0.410      -0.249       0.600
# GFDL-ESM2G        -0.1581      0.174     -0.908      0.368      -0.508       0.192
# MIROC-ESM-CHEM     0.0684      0.188      0.363      0.718      -0.310       0.447
# GFDL-ESM2M         0.1283      0.141      0.909      0.368      -0.155       0.412
# MRI-CGCM3          0.0183      0.086      0.213      0.833      -0.155       0.192
# MRI-CGCM3.1        0.0183      0.086      0.213      0.833      -0.155       0.192
# ==============================================================================
# Omnibus:                       47.494   Durbin-Watson:                   2.017
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              194.032
# Skew:                           2.295   Prob(JB):                     7.35e-43
# Kurtosis:                      10.696   Cond. No.                     2.99e+16
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is 1.2e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
# FOUCHANA FERME GAMOU
#
#
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     FOUCHANA FERME GAMOU   R-squared (uncentered):                   0.742
# Model:                              OLS   Adj. R-squared (uncentered):              0.688
# Method:                   Least Squares   F-statistic:                              13.82
# Date:                  Fri, 22 Jul 2022   Prob (F-statistic):                    4.88e-11
# Time:                          11:11:21   Log-Likelihood:                         -265.91
# No. Observations:                    58   AIC:                                      551.8
# Df Residuals:                        48   BIC:                                      572.4
# Df Model:                            10
# Covariance Type:              nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.4128      0.161      2.568      0.013       0.090       0.736
# CNRM-CM5           0.0437      0.141      0.310      0.758      -0.240       0.327
# CanESM2            0.1536      0.167      0.919      0.363      -0.182       0.490
# FGOALS-s2         -0.0819      0.163     -0.502      0.618      -0.410       0.246
# BNU-ESM            0.2490      0.227      1.097      0.278      -0.208       0.706
# MIROC5             0.1457      0.189      0.770      0.445      -0.235       0.526
# GFDL-ESM2G        -0.2916      0.156     -1.869      0.068      -0.605       0.022
# MIROC-ESM-CHEM     0.0564      0.169      0.334      0.740      -0.283       0.396
# GFDL-ESM2M         0.1790      0.126      1.416      0.163      -0.075       0.433
# MRI-CGCM3          0.0865      0.077      1.121      0.268      -0.069       0.242
# MRI-CGCM3.1        0.0865      0.077      1.121      0.268      -0.069       0.242
# ==============================================================================
# Omnibus:                       11.779   Durbin-Watson:                   2.337
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               12.692
# Skew:                           0.889   Prob(JB):                      0.00175
# Kurtosis:                       4.445   Cond. No.                     2.99e+16
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is 1.2e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
# HAMMEM LIF
#
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             HAMMEM LIF   R-squared (uncentered):                   0.658
# Model:                            OLS   Adj. R-squared (uncentered):              0.587
# Method:                 Least Squares   F-statistic:                              9.235
# Date:                Fri, 22 Jul 2022   Prob (F-statistic):                    2.74e-08
# Time:                        11:11:21   Log-Likelihood:                         -267.37
# No. Observations:                  58   AIC:                                      554.7
# Df Residuals:                      48   BIC:                                      575.3
# Df Model:                          10
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.3454      0.165      2.095      0.042       0.014       0.677
# CNRM-CM5          -0.1568      0.144     -1.086      0.283      -0.447       0.134
# CanESM2            0.2778      0.171      1.621      0.112      -0.067       0.622
# FGOALS-s2         -0.1767      0.167     -1.057      0.296      -0.513       0.160
# BNU-ESM            0.2185      0.233      0.938      0.353      -0.250       0.687
# MIROC5             0.1074      0.194      0.553      0.583      -0.283       0.498
# GFDL-ESM2G        -0.2128      0.160     -1.330      0.190      -0.535       0.109
# MIROC-ESM-CHEM     0.1457      0.173      0.842      0.404      -0.202       0.494
# GFDL-ESM2M         0.1903      0.130      1.467      0.149      -0.070       0.451
# MRI-CGCM3          0.0781      0.079      0.986      0.329      -0.081       0.237
# MRI-CGCM3.1        0.0781      0.079      0.986      0.329      -0.081       0.237
# ==============================================================================
# Omnibus:                       57.505   Durbin-Watson:                   2.124
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              441.683
# Skew:                           2.545   Prob(JB):                     1.23e-96
# Kurtosis:                      15.524   Cond. No.                     2.99e+16
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is 1.2e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
# KHELIDIA CTV
#
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:           KHELIDIA CTV   R-squared (uncentered):                   0.741
# Model:                            OLS   Adj. R-squared (uncentered):              0.687
# Method:                 Least Squares   F-statistic:                              13.72
# Date:                Fri, 22 Jul 2022   Prob (F-statistic):                    5.52e-11
# Time:                        11:11:21   Log-Likelihood:                         -265.25
# No. Observations:                  58   AIC:                                      550.5
# Df Residuals:                      48   BIC:                                      571.1
# Df Model:                          10
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.3696      0.159      2.325      0.024       0.050       0.689
# CNRM-CM5           0.0041      0.139      0.029      0.977      -0.276       0.284
# CanESM2            0.0899      0.165      0.544      0.589      -0.242       0.422
# FGOALS-s2         -0.0699      0.161     -0.434      0.667      -0.394       0.254
# BNU-ESM            0.4090      0.224      1.822      0.075      -0.042       0.860
# MIROC5             0.1966      0.187      1.050      0.299      -0.180       0.573
# GFDL-ESM2G        -0.3387      0.154     -2.196      0.033      -0.649      -0.029
# MIROC-ESM-CHEM     0.0849      0.167      0.509      0.613      -0.251       0.420
# GFDL-ESM2M         0.1711      0.125      1.369      0.177      -0.080       0.422
# MRI-CGCM3          0.0549      0.076      0.719      0.476      -0.099       0.208
# MRI-CGCM3.1        0.0549      0.076      0.719      0.476      -0.099       0.208
# ==============================================================================
# Omnibus:                       26.964   Durbin-Watson:                   2.201
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               50.685
# Skew:                           1.509   Prob(JB):                     9.86e-12
# Kurtosis:                       6.444   Cond. No.                     2.99e+16
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is 1.2e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
# KHELIDIA POMPAGE
#
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:       KHELIDIA POMPAGE   R-squared (uncentered):                   0.730
# Model:                            OLS   Adj. R-squared (uncentered):              0.674
# Method:                 Least Squares   F-statistic:                              12.97
# Date:                Fri, 22 Jul 2022   Prob (F-statistic):                    1.40e-10
# Time:                        11:11:21   Log-Likelihood:                         -261.74
# No. Observations:                  58   AIC:                                      543.5
# Df Residuals:                      48   BIC:                                      564.1
# Df Model:                          10
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.2910      0.150      1.945      0.058      -0.010       0.592
# CNRM-CM5          -0.0198      0.131     -0.151      0.880      -0.283       0.244
# CanESM2            0.1304      0.156      0.839      0.406      -0.182       0.443
# FGOALS-s2         -0.0819      0.152     -0.540      0.592      -0.387       0.223
# BNU-ESM            0.3197      0.211      1.513      0.137      -0.105       0.745
# MIROC5             0.1403      0.176      0.796      0.430      -0.214       0.495
# GFDL-ESM2G        -0.2891      0.145     -1.991      0.052      -0.581       0.003
# MIROC-ESM-CHEM     0.1432      0.157      0.912      0.366      -0.173       0.459
# GFDL-ESM2M         0.1996      0.118      1.696      0.096      -0.037       0.436
# MRI-CGCM3          0.0559      0.072      0.777      0.441      -0.089       0.200
# MRI-CGCM3.1        0.0559      0.072      0.777      0.441      -0.089       0.200
# ==============================================================================
# Omnibus:                       26.913   Durbin-Watson:                   2.264
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               49.773
# Skew:                           1.519   Prob(JB):                     1.56e-11
# Kurtosis:                       6.372   Cond. No.                     2.99e+16
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is 1.2e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
# MEGRINE PARC CRDA
#
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:      MEGRINE PARC CRDA   R-squared (uncentered):                   0.714
# Model:                            OLS   Adj. R-squared (uncentered):              0.654
# Method:                 Least Squares   F-statistic:                              11.96
# Date:                Fri, 22 Jul 2022   Prob (F-statistic):                    5.23e-10
# Time:                        11:11:21   Log-Likelihood:                         -268.71
# No. Observations:                  58   AIC:                                      557.4
# Df Residuals:                      48   BIC:                                      578.0
# Df Model:                          10
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.4071      0.169      2.413      0.020       0.068       0.746
# CNRM-CM5          -0.0300      0.148     -0.203      0.840      -0.327       0.267
# CanESM2            0.1441      0.175      0.822      0.415      -0.208       0.497
# FGOALS-s2         -0.1263      0.171     -0.738      0.464      -0.470       0.218
# BNU-ESM            0.2961      0.238      1.243      0.220      -0.183       0.775
# MIROC5             0.2249      0.199      1.132      0.263      -0.175       0.624
# GFDL-ESM2G        -0.2176      0.164     -1.329      0.190      -0.547       0.112
# MIROC-ESM-CHEM     0.0230      0.177      0.130      0.897      -0.333       0.379
# GFDL-ESM2M         0.1555      0.133      1.172      0.247      -0.111       0.422
# MRI-CGCM3          0.0739      0.081      0.913      0.366      -0.089       0.237
# MRI-CGCM3.1        0.0739      0.081      0.913      0.366      -0.089       0.237
# ==============================================================================
# Omnibus:                       38.707   Durbin-Watson:                   2.251
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              143.451
# Skew:                           1.796   Prob(JB):                     7.08e-32
# Kurtosis:                       9.816   Cond. No.                     2.99e+16
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is 1.2e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
# MHAMEDIA DISPENSAIRE
#
#
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     MHAMEDIA DISPENSAIRE   R-squared (uncentered):                   0.656
# Model:                              OLS   Adj. R-squared (uncentered):              0.584
# Method:                   Least Squares   F-statistic:                              9.146
# Date:                  Fri, 22 Jul 2022   Prob (F-statistic):                    3.15e-08
# Time:                          11:11:21   Log-Likelihood:                         -275.13
# No. Observations:                    58   AIC:                                      570.3
# Df Residuals:                        48   BIC:                                      590.9
# Df Model:                            10
# Covariance Type:              nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.3459      0.188      1.835      0.073      -0.033       0.725
# CNRM-CM5           0.0123      0.165      0.075      0.941      -0.320       0.344
# CanESM2            0.1722      0.196      0.879      0.384      -0.222       0.566
# FGOALS-s2         -0.0759      0.191     -0.397      0.693      -0.460       0.309
# BNU-ESM            0.3009      0.266      1.130      0.264      -0.234       0.836
# MIROC5             0.2074      0.222      0.934      0.355      -0.239       0.654
# GFDL-ESM2G        -0.2508      0.183     -1.371      0.177      -0.619       0.117
# MIROC-ESM-CHEM     0.0798      0.198      0.404      0.688      -0.318       0.478
# GFDL-ESM2M         0.1348      0.148      0.910      0.368      -0.163       0.433
# MRI-CGCM3          0.0383      0.091      0.424      0.674      -0.144       0.220
# MRI-CGCM3.1        0.0383      0.091      0.424      0.674      -0.144       0.220
# ==============================================================================
# Omnibus:                       58.132   Durbin-Watson:                   2.204
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              397.261
# Skew:                           2.663   Prob(JB):                     5.44e-87
# Kurtosis:                      14.662   Cond. No.                     2.99e+16
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is 1.2e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
# MORNAG SIDI ZEYED
#
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:      MORNAG SIDI ZEYED   R-squared (uncentered):                   0.677
# Model:                            OLS   Adj. R-squared (uncentered):              0.609
# Method:                 Least Squares   F-statistic:                              10.05
# Date:                Fri, 22 Jul 2022   Prob (F-statistic):                    7.89e-09
# Time:                        11:11:21   Log-Likelihood:                         -276.25
# No. Observations:                  58   AIC:                                      572.5
# Df Residuals:                      48   BIC:                                      593.1
# Df Model:                          10
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.3856      0.192      2.006      0.050      -0.001       0.772
# CNRM-CM5          -0.0079      0.168     -0.047      0.963      -0.346       0.331
# CanESM2            0.1489      0.200      0.746      0.460      -0.253       0.550
# FGOALS-s2         -0.1526      0.195     -0.783      0.438      -0.545       0.239
# BNU-ESM            0.4349      0.271      1.602      0.116      -0.111       0.981
# MIROC5             0.2127      0.226      0.940      0.352      -0.242       0.668
# GFDL-ESM2G        -0.2643      0.187     -1.417      0.163      -0.639       0.111
# MIROC-ESM-CHEM     0.1090      0.202      0.540      0.592      -0.297       0.515
# GFDL-ESM2M         0.1048      0.151      0.694      0.491      -0.199       0.409
# MRI-CGCM3          0.0547      0.092      0.593      0.556      -0.131       0.240
# MRI-CGCM3.1        0.0547      0.092      0.593      0.556      -0.131       0.240
# ==============================================================================
# Omnibus:                       44.555   Durbin-Watson:                   2.170
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              162.219
# Skew:                           2.180   Prob(JB):                     5.95e-36
# Kurtosis:                       9.936   Cond. No.                     2.99e+16
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is 1.2e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
# MORNEG CTV
#
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             MORNEG CTV   R-squared (uncentered):                   0.683
# Model:                            OLS   Adj. R-squared (uncentered):              0.617
# Method:                 Least Squares   F-statistic:                              10.34
# Date:                Fri, 22 Jul 2022   Prob (F-statistic):                    5.12e-09
# Time:                        11:11:21   Log-Likelihood:                         -279.01
# No. Observations:                  58   AIC:                                      578.0
# Df Residuals:                      48   BIC:                                      598.6
# Df Model:                          10
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.4126      0.202      2.048      0.046       0.007       0.818
# CNRM-CM5          -0.0446      0.177     -0.252      0.802      -0.400       0.310
# CanESM2            0.1797      0.209      0.858      0.395      -0.241       0.601
# FGOALS-s2         -0.2016      0.204     -0.986      0.329      -0.613       0.209
# BNU-ESM            0.4981      0.285      1.750      0.087      -0.074       1.070
# MIROC5             0.2013      0.237      0.848      0.400      -0.276       0.678
# GFDL-ESM2G        -0.2681      0.196     -1.371      0.177      -0.661       0.125
# MIROC-ESM-CHEM     0.1328      0.212      0.628      0.533      -0.293       0.558
# GFDL-ESM2M         0.1184      0.158      0.747      0.459      -0.200       0.437
# MRI-CGCM3          0.0630      0.097      0.651      0.518      -0.132       0.258
# MRI-CGCM3.1        0.0630      0.097      0.651      0.518      -0.132       0.258
# ==============================================================================
# Omnibus:                       54.816   Durbin-Watson:                   2.181
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              346.336
# Skew:                           2.490   Prob(JB):                     6.23e-76
# Kurtosis:                      13.886   Cond. No.                     2.99e+16
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is 1.2e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
# MORNEG FERME ESSADIR
#
#
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     MORNEG FERME ESSADIR   R-squared (uncentered):                   0.694
# Model:                              OLS   Adj. R-squared (uncentered):              0.630
# Method:                   Least Squares   F-statistic:                              10.88
# Date:                  Fri, 22 Jul 2022   Prob (F-statistic):                    2.35e-09
# Time:                          11:11:21   Log-Likelihood:                         -271.88
# No. Observations:                    58   AIC:                                      563.8
# Df Residuals:                        48   BIC:                                      584.4
# Df Model:                            10
# Covariance Type:              nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.4285      0.178      2.404      0.020       0.070       0.787
# CNRM-CM5          -0.0088      0.156     -0.056      0.955      -0.323       0.305
# CanESM2            0.1332      0.185      0.719      0.475      -0.239       0.506
# FGOALS-s2         -0.1975      0.181     -1.092      0.280      -0.561       0.166
# BNU-ESM            0.4456      0.252      1.770      0.083      -0.061       0.952
# MIROC5             0.2114      0.210      1.007      0.319      -0.211       0.633
# GFDL-ESM2G        -0.2937      0.173     -1.698      0.096      -0.641       0.054
# MIROC-ESM-CHEM     0.1191      0.187      0.637      0.527      -0.257       0.495
# GFDL-ESM2M         0.1136      0.140      0.810      0.422      -0.168       0.395
# MRI-CGCM3          0.0490      0.086      0.572      0.570      -0.123       0.221
# MRI-CGCM3.1        0.0490      0.086      0.572      0.570      -0.123       0.221
# ==============================================================================
# Omnibus:                       48.616   Durbin-Watson:                   2.178
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              237.601
# Skew:                           2.248   Prob(JB):                     2.54e-52
# Kurtosis:                      11.838   Cond. No.                     2.99e+16
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is 1.2e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
# OUDHNA FERME CHIBOUB
#
#
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     OUDHNA FERME CHIBOUB   R-squared (uncentered):                   0.701
# Model:                              OLS   Adj. R-squared (uncentered):              0.639
# Method:                   Least Squares   F-statistic:                              11.26
# Date:                  Fri, 22 Jul 2022   Prob (F-statistic):                    1.37e-09
# Time:                          11:11:21   Log-Likelihood:                         -252.97
# No. Observations:                    58   AIC:                                      525.9
# Df Residuals:                        48   BIC:                                      546.5
# Df Model:                            10
# Covariance Type:              nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.3748      0.129      2.914      0.005       0.116       0.633
# CNRM-CM5           0.0739      0.113      0.656      0.515      -0.153       0.300
# CanESM2            0.1086      0.134      0.812      0.421      -0.160       0.377
# FGOALS-s2         -0.1809      0.130     -1.386      0.172      -0.443       0.081
# BNU-ESM            0.2038      0.182      1.122      0.268      -0.161       0.569
# MIROC5             0.1525      0.151      1.007      0.319      -0.152       0.457
# GFDL-ESM2G        -0.2339      0.125     -1.874      0.067      -0.485       0.017
# MIROC-ESM-CHEM     0.0103      0.135      0.076      0.940      -0.261       0.282
# GFDL-ESM2M         0.1510      0.101      1.493      0.142      -0.052       0.354
# MRI-CGCM3          0.0482      0.062      0.781      0.439      -0.076       0.172
# MRI-CGCM3.1        0.0482      0.062      0.781      0.439      -0.076       0.172
# ==============================================================================
# Omnibus:                       34.641   Durbin-Watson:                   2.204
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               92.207
# Skew:                           1.755   Prob(JB):                     9.50e-21
# Kurtosis:                       8.083   Cond. No.                     2.99e+16
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is 1.2e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
# OUZRA AGRI FLORA
#
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:       OUZRA AGRI FLORA   R-squared (uncentered):                   0.677
# Model:                            OLS   Adj. R-squared (uncentered):              0.610
# Method:                 Least Squares   F-statistic:                              10.06
# Date:                Fri, 22 Jul 2022   Prob (F-statistic):                    7.78e-09
# Time:                        11:11:22   Log-Likelihood:                         -269.66
# No. Observations:                  58   AIC:                                      559.3
# Df Residuals:                      48   BIC:                                      579.9
# Df Model:                          10
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.3389      0.172      1.976      0.054      -0.006       0.684
# CNRM-CM5          -0.0237      0.150     -0.158      0.875      -0.326       0.278
# CanESM2            0.0317      0.178      0.178      0.860      -0.327       0.390
# FGOALS-s2         -0.1161      0.174     -0.667      0.508      -0.466       0.234
# BNU-ESM            0.4175      0.242      1.723      0.091      -0.070       0.905
# MIROC5             0.2828      0.202      1.400      0.168      -0.123       0.689
# GFDL-ESM2G        -0.1953      0.166     -1.173      0.247      -0.530       0.139
# MIROC-ESM-CHEM     0.0671      0.180      0.373      0.711      -0.295       0.429
# GFDL-ESM2M         0.0961      0.135      0.712      0.480      -0.175       0.367
# MRI-CGCM3          0.0299      0.082      0.363      0.718      -0.136       0.196
# MRI-CGCM3.1        0.0299      0.082      0.363      0.718      -0.136       0.196
# ==============================================================================
# Omnibus:                       32.926   Durbin-Watson:                   2.298
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               85.959
# Skew:                           1.660   Prob(JB):                     2.16e-19
# Kurtosis:                       7.955   Cond. No.                     2.99e+16
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is 1.2e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
# RADES OUAFA
#
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:            RADES OUAFA   R-squared (uncentered):                   0.808
# Model:                            OLS   Adj. R-squared (uncentered):              0.768
# Method:                 Least Squares   F-statistic:                              20.19
# Date:                Fri, 22 Jul 2022   Prob (F-statistic):                    5.74e-14
# Time:                        11:11:22   Log-Likelihood:                         -246.65
# No. Observations:                  58   AIC:                                      513.3
# Df Residuals:                      48   BIC:                                      533.9
# Df Model:                          10
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.2422      0.115      2.100      0.041       0.010       0.474
# CNRM-CM5           0.1303      0.101      1.289      0.204      -0.073       0.333
# CanESM2           -0.1064      0.120     -0.887      0.379      -0.347       0.135
# FGOALS-s2         -0.0688      0.117     -0.588      0.559      -0.304       0.166
# BNU-ESM            0.1350      0.163      0.829      0.411      -0.193       0.463
# MIROC5             0.0378      0.136      0.278      0.782      -0.235       0.311
# GFDL-ESM2G        -0.0436      0.112     -0.389      0.699      -0.269       0.182
# MIROC-ESM-CHEM     0.0478      0.121      0.395      0.694      -0.196       0.291
# GFDL-ESM2M         0.2823      0.091      3.112      0.003       0.100       0.465
# MRI-CGCM3          0.0971      0.055      1.753      0.086      -0.014       0.208
# MRI-CGCM3.1        0.0971      0.055      1.753      0.086      -0.014       0.208
# ==============================================================================
# Omnibus:                        2.221   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.329   Jarque-Bera (JB):                2.147
# Skew:                          -0.410   Prob(JB):                        0.342
# Kurtosis:                       2.534   Cond. No.                     2.99e+16
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is 1.2e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
#
# RADES PF
#
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               RADES PF   R-squared (uncentered):                   0.712
# Model:                            OLS   Adj. R-squared (uncentered):              0.652
# Method:                 Least Squares   F-statistic:                              11.88
# Date:                Fri, 22 Jul 2022   Prob (F-statistic):                    5.81e-10
# Time:                        11:11:22   Log-Likelihood:                         -259.12
# No. Observations:                  58   AIC:                                      538.2
# Df Residuals:                      48   BIC:                                      558.8
# Df Model:                          10
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.3822      0.143      2.673      0.010       0.095       0.670
# CNRM-CM5          -0.0100      0.125     -0.079      0.937      -0.262       0.242
# CanESM2            0.1546      0.149      1.040      0.303      -0.144       0.454
# FGOALS-s2         -0.0933      0.145     -0.643      0.523      -0.385       0.198
# BNU-ESM            0.1716      0.202      0.850      0.400      -0.235       0.578
# MIROC5             0.1574      0.168      0.935      0.355      -0.181       0.496
# GFDL-ESM2G        -0.1924      0.139     -1.386      0.172      -0.471       0.087
# MIROC-ESM-CHEM     0.0738      0.150      0.492      0.625      -0.228       0.376
# GFDL-ESM2M         0.1013      0.112      0.900      0.372      -0.125       0.327
# MRI-CGCM3          0.0638      0.069      0.929      0.358      -0.074       0.202
# MRI-CGCM3.1        0.0638      0.069      0.929      0.358      -0.074       0.202
# ==============================================================================
# Omnibus:                       20.374   Durbin-Watson:                   2.436
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               31.917
# Skew:                           1.208   Prob(JB):                     1.17e-07
# Kurtosis:                       5.715   Cond. No.                     2.99e+16
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is 1.2e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
RCP45Crossed.columns
# Out:
# Index(['MIROC-ESM', 'CNRM-CM5', 'CanESM2', 'FGOALS-s2', 'BNU-ESM', 'MIROC5',
#        'GFDL-ESM2G', 'MIROC-ESM-CHEM', 'GFDL-ESM2M', 'MRI-CGCM3',
#        'MRI-CGCM3.1', 'Month', 'Year', 'BEN AROUS I MUNICIPA',
#        'BOUMHEL BASSATINE MU', 'CRETEVILLE', 'DOMAINE DECHAMUNE', 'EZZAHRA',
#        'FOUCHANA FERME GAMOU', 'HAMMEM LIF', 'KHELIDIA CTV',
#        'KHELIDIA POMPAGE', 'MEGRINE PARC CRDA', 'MHAMEDIA DISPENSAIRE',
#        'MORNAG SIDI ZEYED', 'MORNEG CTV', 'MORNEG FERME ESSADIR',
#        'OUDHNA FERME CHIBOUB', 'OUZRA AGRI FLORA', 'RADES OUAFA', 'RADES PF'],
#       dtype='object')

# %%
rmseDataLR[["RG","RMSE","Adj. R-squared","AIC","BIC"]].sort_values(by=['Adj. R-squared'],ascending=False).head(1)
# Out:
#              RG       RMSE  Adj. R-squared         AIC         BIC
# 16  RADES OUAFA  24.517621        0.767941  513.294594  533.899024

# %%
storage1V1=list()
for i in range(13,len(RCP45Crossed.columns)):
    for j in range(0,10):
        RMSE=np.sqrt(mean_squared_error(RCP45Crossed[RCP45Crossed.columns[i]],RCP45Crossed[RCP45Crossed.columns[j]]))
        storage1V1.append(
            {
                'RG':RCP45Crossed.columns[i],
                'MODEL':RCP45Crossed.columns[j],
                'RMSE':  RMSE,

            }
        )
rmseData1V1=pd.DataFrame(storage1V1)

# %%
rmseData1V1.groupby(['MODEL']).min(['RMSE'])
# Out:
#                      RMSE
# MODEL
# BNU-ESM         26.486775
# CNRM-CM5        35.174819
# CanESM2         28.654172
# FGOALS-s2       32.299446
# GFDL-ESM2G      34.914069
# GFDL-ESM2M      34.597031
# MIROC-ESM       28.108184
# MIROC-ESM-CHEM  28.453556
# MIROC5          30.104213
# MRI-CGCM3       30.496024

# %%
RCP45.index=RCP45.date
date=RCP45['date']
del RCP45['date']

# %%
RCP45["MonthlyRF"]=0.0
est=rmseDataLR["est"][16]
for i in range(0,len(est.params)):
    RCP45["MonthlyRF"]+=est.params[i]*RCP45[RCP45.columns[i]]
RCP45["MonthlyRF"][RCP45["MonthlyRF"]<0.0]=0.0

# %%
RCP45["Mean"] = RCP45.loc[:, ['MIROC-ESM', 'CNRM-CM5', 'CanESM2', 'FGOALS-s2', 'BNU-ESM',
       'MIROC5', 'GFDL-ESM2G', 'MIROC-ESM-CHEM', 'GFDL-ESM2M', 'MRI-CGCM3',
       'MRI-CGCM3.1']].mean(axis = 1)
RCP45.to_pickle("./Pickles/Data/RCP45Complete.pkl")
RCP45=RCP45[['Month','Year','MonthlyRF','Mean']].copy()
RCP45['date']=date

# %%
RCP45['sem']= RCP45.date.dt.year.astype(str) + 'S'+ np.where(RCP45.date.dt.quarter.gt(2),2,1).astype(str)
RCP45['trim']= RCP45.date.dt.year.astype(str) + 'T'+ RCP45.date.dt.quarter.astype(str)

# %%
SPI=(RCP45['Mean']-RCP45['Mean'].mean())/RCP45['Mean'].std()#SPI Calculation 
RCP45['SPI']=SPI#Creating a new column for the SPI

# %%
RCP45['SPI_classes']=""#Creating a new column for the interpretation of the spi
for i in range(0,len(RCP45)):
    if(RCP45['SPI'].values[i]>2):#SPI>2
        RCP45['SPI_classes'].values[i]="Extremely wet"
    elif((RCP45['SPI'].values[i]< 2) & (RCP45['SPI'].values[i] >1)):#1<SPI< 2
        RCP45['SPI_classes'].values[i]="Very wet"
    elif((RCP45['SPI'].values[i]< 1) & (RCP45['SPI'].values[i] >0)):#0<SPI< 1
        RCP45['SPI_classes'].values[i]="Moderately Wet"
    elif((RCP45['SPI'].values[i] >-1 )&( RCP45['SPI'].values[i] <0)):#-1<SPI< 0
        RCP45['SPI_classes'].values[i]="Moderately dry"
    elif((RCP45['SPI'].values[i] >-2 )&( RCP45['SPI'].values[i] <-1)):#-2<SPI<-1
        RCP45['SPI_classes'].values[i]="Severely dry"
    else :#SPI< -2
        RCP45['SPI_classes'].values[i]="Extremely dry"

# %%
dfSem=RCP45.copy()
dfSem=dfSem.groupby(['sem',]).sum('Mean')#Summing Rainfall on Pluviometer and Semester
dfSem.drop(columns=['Month','Year','MonthlyRF','SPI'],axis=1,inplace=True)#Droping the unuseful columns
dfSem.rename(columns = {'Mean':'SemestrialRF'}, inplace = True)#Renaming P to MonthlyP for more clarity

# %%
dfTrim=RCP45.copy()
dfTrim=dfTrim.groupby(['trim']).sum('Mean')#Summing Rainfall on Pluviometer and Trimestre
dfTrim.drop(columns=['Month','Year','MonthlyRF','SPI'],axis=1,inplace=True)#Droping the unuseful columns
dfTrim.rename(columns = {'Mean':'TrimestrialRF'}, inplace = True)#Renaming RF to TrimestrialRF for more clarity

# %%
dfyear=RCP45.copy()
dfyear=dfyear.groupby(['Year']).sum('Mean')#Summing Rainfall on Pluviometer and Trimestre
dfyear.drop(columns=['Month','MonthlyRF','SPI'],axis=1,inplace=True)#Droping the unuseful columns
dfyear.rename(columns = {'Mean':'YearlyRF'}, inplace = True)#Renaming RF to TrimestrialRF for more clarity

# %%
RCP45 = pd.merge(RCP45,dfyear, on=['Year'], how='inner')#Merging the zone with the pluviometric data on Rain Gauge
RCP45 = pd.merge(RCP45,dfSem, on=['sem'], how='inner')#Merging the zone with the pluviometric data on Rain Gauge
RCP45 = pd.merge(RCP45,dfTrim, on=['trim'], how='inner')#Merging the zone with the pluviometric data on Rain Gauge

# %%
RCP45
# Out:
#       Month  Year  MonthlyRF       Mean       date     sem    trim       SPI  \
# 0         1  2009  32.339427  32.587273 2009-01-01  2009S1  2009T1  0.034115
# 1         2  2009  58.941928  68.960000 2009-02-01  2009S1  2009T1  2.144191
# 2         3  2009  58.930666  56.940909 2009-03-01  2009S1  2009T1  1.446933
# 3         4  2009  19.653141  21.307273 2009-04-01  2009S1  2009T2 -0.620267
# 4         5  2009  51.607003  43.026364 2009-05-01  2009S1  2009T2  0.639714
# ...     ...   ...        ...        ...        ...     ...     ...       ...
# 1099      8  2100  11.403540  11.966289 2100-08-01  2100S2  2100T3 -1.162161
# 1100      9  2100  13.328279  20.117198 2100-09-01  2100S2  2100T3 -0.689306
# 1101     10  2100  19.810783  28.515380 2100-10-01  2100S2  2100T4 -0.202106
# 1102     11  2100  28.210180  37.123561 2100-11-01  2100S2  2100T4  0.297277
# 1103     12  2100  20.193310  31.990834 2100-12-01  2100S2  2100T4 -0.000486
#
#          SPI_classes    YearlyRF  SemestrialRF  TrimestrialRF
# 0     Moderately Wet  411.898182    273.444545     158.488182
# 1      Extremely wet  411.898182    273.444545     158.488182
# 2           Very wet  411.898182    273.444545     158.488182
# 3     Moderately dry  411.898182    273.444545     114.956364
# 4     Moderately Wet  411.898182    273.444545     114.956364
# ...              ...         ...           ...            ...
# 1099    Severely dry  312.445465    149.702278      52.072502
# 1100  Moderately dry  312.445465    149.702278      52.072502
# 1101  Moderately dry  312.445465    149.702278      97.629775
# 1102  Moderately Wet  312.445465    149.702278      97.629775
# 1103  Moderately dry  312.445465    149.702278      97.629775
#
# [1104 rows x 12 columns]

# %%
df1 = pd.DataFrame({'Pluviometer' : data_rain["Pluviometer"].unique()})

# %%
RCP45 = pd.DataFrame(np.repeat(RCP45.values, 18, axis=0), columns=RCP45.columns)
df1=df1.append([df1] * 1104, ignore_index=True)

# %%
RCP45=RCP45.join(df1)
RCP45.index=RCP45.date

# %%
RCP45
# Out:
#            Month  Year  MonthlyRF       Mean       date     sem    trim  \
# date
# 2009-01-01     1  2009  32.339427  32.587273 2009-01-01  2009S1  2009T1
# 2009-01-01     1  2009  32.339427  32.587273 2009-01-01  2009S1  2009T1
# 2009-01-01     1  2009  32.339427  32.587273 2009-01-01  2009S1  2009T1
# 2009-01-01     1  2009  32.339427  32.587273 2009-01-01  2009S1  2009T1
# 2009-01-01     1  2009  32.339427  32.587273 2009-01-01  2009S1  2009T1
# ...          ...   ...        ...        ...        ...     ...     ...
# 2100-12-01    12  2100   20.19331  31.990834 2100-12-01  2100S2  2100T4
# 2100-12-01    12  2100   20.19331  31.990834 2100-12-01  2100S2  2100T4
# 2100-12-01    12  2100   20.19331  31.990834 2100-12-01  2100S2  2100T4
# 2100-12-01    12  2100   20.19331  31.990834 2100-12-01  2100S2  2100T4
# 2100-12-01    12  2100   20.19331  31.990834 2100-12-01  2100S2  2100T4
#
#                  SPI     SPI_classes    YearlyRF SemestrialRF TrimestrialRF  \
# date
# 2009-01-01  0.034115  Moderately Wet  411.898182   273.444545    158.488182
# 2009-01-01  0.034115  Moderately Wet  411.898182   273.444545    158.488182
# 2009-01-01  0.034115  Moderately Wet  411.898182   273.444545    158.488182
# 2009-01-01  0.034115  Moderately Wet  411.898182   273.444545    158.488182
# 2009-01-01  0.034115  Moderately Wet  411.898182   273.444545    158.488182
# ...              ...             ...         ...          ...           ...
# 2100-12-01 -0.000486  Moderately dry  312.445465   149.702278     97.629775
# 2100-12-01 -0.000486  Moderately dry  312.445465   149.702278     97.629775
# 2100-12-01 -0.000486  Moderately dry  312.445465   149.702278     97.629775
# 2100-12-01 -0.000486  Moderately dry  312.445465   149.702278     97.629775
# 2100-12-01 -0.000486  Moderately dry  312.445465   149.702278     97.629775
#
#                      Pluviometer
# date
# 2009-01-01  BEN AROUS I MUNICIPA
# 2009-01-01  BOUMHEL BASSATINE MU
# 2009-01-01            CRETEVILLE
# 2009-01-01     DOMAINE DECHAMUNE
# 2009-01-01               EZZAHRA
# ...                          ...
# 2100-12-01  MORNEG FERME ESSADIR
# 2100-12-01  OUDHNA FERME CHIBOUB
# 2100-12-01      OUZRA AGRI FLORA
# 2100-12-01           RADES OUAFA
# 2100-12-01              RADES PF
#
# [19872 rows x 13 columns]

# %%
data_rain1=data_rain[['Pluviometer','Lat_Pluviometer','Lon_Pluviometer','Zone']].copy()
data_rain1.drop_duplicates(keep="first",inplace=True)
RCP45= pd.merge(RCP45,data_rain1,on=['Pluviometer'], how='inner')#Merging piezometric data and pluviometric data on sem and zone
RCP45
# Out:
#       Month  Year  MonthlyRF       Mean       date     sem    trim       SPI  \
# 0         1  2009  32.339427  32.587273 2009-01-01  2009S1  2009T1  0.034115
# 1         2  2009  58.941928      68.96 2009-02-01  2009S1  2009T1  2.144191
# 2         3  2009  58.930666  56.940909 2009-03-01  2009S1  2009T1  1.446933
# 3         4  2009  19.653141  21.307273 2009-04-01  2009S1  2009T2 -0.620267
# 4         5  2009  51.607003  43.026364 2009-05-01  2009S1  2009T2  0.639714
# ...     ...   ...        ...        ...        ...     ...     ...       ...
# 19867     8  2100   11.40354  11.966289 2100-08-01  2100S2  2100T3 -1.162161
# 19868     9  2100  13.328279  20.117198 2100-09-01  2100S2  2100T3 -0.689306
# 19869    10  2100  19.810783   28.51538 2100-10-01  2100S2  2100T4 -0.202106
# 19870    11  2100   28.21018  37.123561 2100-11-01  2100S2  2100T4  0.297277
# 19871    12  2100   20.19331  31.990834 2100-12-01  2100S2  2100T4 -0.000486
#
#           SPI_classes    YearlyRF SemestrialRF TrimestrialRF  \
# 0      Moderately Wet  411.898182   273.444545    158.488182
# 1       Extremely wet  411.898182   273.444545    158.488182
# 2            Very wet  411.898182   273.444545    158.488182
# 3      Moderately dry  411.898182   273.444545    114.956364
# 4      Moderately Wet  411.898182   273.444545    114.956364
# ...               ...         ...          ...           ...
# 19867    Severely dry  312.445465   149.702278     52.072502
# 19868  Moderately dry  312.445465   149.702278     52.072502
# 19869  Moderately dry  312.445465   149.702278     97.629775
# 19870  Moderately Wet  312.445465   149.702278     97.629775
# 19871  Moderately dry  312.445465   149.702278     97.629775
#
#                 Pluviometer  Lat_Pluviometer  Lon_Pluviometer  Zone
# 0      BEN AROUS I MUNICIPA         36.76500        -10.22111     4
# 1      BEN AROUS I MUNICIPA         36.76500        -10.22111     4
# 2      BEN AROUS I MUNICIPA         36.76500        -10.22111     4
# 3      BEN AROUS I MUNICIPA         36.76500        -10.22111     4
# 4      BEN AROUS I MUNICIPA         36.76500        -10.22111     4
# ...                     ...              ...              ...   ...
# 19867              RADES PF         36.75222        -10.26361     4
# 19868              RADES PF         36.75222        -10.26361     4
# 19869              RADES PF         36.75222        -10.26361     4
# 19870              RADES PF         36.75222        -10.26361     4
# 19871              RADES PF         36.75222        -10.26361     4
#
# [19872 rows x 16 columns]

# %%
data_piezo1=data_piezo[["Piezometer",'Lat','Lon','Zone']]
data_piezo1.drop_duplicates(keep="first",inplace=True)
RCP45= pd.merge(RCP45,data_piezo1,on=['Zone'], how='inner')#Merging piezometric data and pluviometric data on sem and zone
RCP45
# Out:
#        Month  Year  MonthlyRF       Mean       date     sem    trim       SPI  \
# 0          1  2009  32.339427  32.587273 2009-01-01  2009S1  2009T1  0.034115
# 1          1  2009  32.339427  32.587273 2009-01-01  2009S1  2009T1  0.034115
# 2          1  2009  32.339427  32.587273 2009-01-01  2009S1  2009T1  0.034115
# 3          1  2009  32.339427  32.587273 2009-01-01  2009S1  2009T1  0.034115
# 4          1  2009  32.339427  32.587273 2009-01-01  2009S1  2009T1  0.034115
# ...      ...   ...        ...        ...        ...     ...     ...       ...
# 172219    12  2100   20.19331  31.990834 2100-12-01  2100S2  2100T4 -0.000486
# 172220    12  2100   20.19331  31.990834 2100-12-01  2100S2  2100T4 -0.000486
# 172221    12  2100   20.19331  31.990834 2100-12-01  2100S2  2100T4 -0.000486
# 172222    12  2100   20.19331  31.990834 2100-12-01  2100S2  2100T4 -0.000486
# 172223    12  2100   20.19331  31.990834 2100-12-01  2100S2  2100T4 -0.000486
#
#            SPI_classes    YearlyRF SemestrialRF TrimestrialRF  \
# 0       Moderately Wet  411.898182   273.444545    158.488182
# 1       Moderately Wet  411.898182   273.444545    158.488182
# 2       Moderately Wet  411.898182   273.444545    158.488182
# 3       Moderately Wet  411.898182   273.444545    158.488182
# 4       Moderately Wet  411.898182   273.444545    158.488182
# ...                ...         ...          ...           ...
# 172219  Moderately dry  312.445465   149.702278     97.629775
# 172220  Moderately dry  312.445465   149.702278     97.629775
# 172221  Moderately dry  312.445465   149.702278     97.629775
# 172222  Moderately dry  312.445465   149.702278     97.629775
# 172223  Moderately dry  312.445465   149.702278     97.629775
#
#                  Pluviometer  Lat_Pluviometer  Lon_Pluviometer  Zone  \
# 0       BEN AROUS I MUNICIPA         36.76500        -10.22111     4
# 1       BEN AROUS I MUNICIPA         36.76500        -10.22111     4
# 2       BEN AROUS I MUNICIPA         36.76500        -10.22111     4
# 3       BEN AROUS I MUNICIPA         36.76500        -10.22111     4
# 4       BEN AROUS I MUNICIPA         36.76500        -10.22111     4
# ...                      ...              ...              ...   ...
# 172219      OUZRA AGRI FLORA         36.62639        -10.25639     1
# 172220      OUZRA AGRI FLORA         36.62639        -10.25639     1
# 172221      OUZRA AGRI FLORA         36.62639        -10.25639     1
# 172222      OUZRA AGRI FLORA         36.62639        -10.25639     1
# 172223      OUZRA AGRI FLORA         36.62639        -10.25639     1
#
#              Piezometer        Lat        Lon
# 0             Ben Zazia  36.712677  10.296590
# 1                  Fraj  36.721854  10.300582
# 2            Bir El Kif  36.717664  10.294973
# 3              El Attar  36.728039  10.314714
# 4                Majoul  36.736674  10.273134
# ...                 ...        ...        ...
# 172219        UCP Ouzra  36.650512  10.231095
# 172220     Salah Khamar  36.653313  10.191087
# 172221    Haj Hadi Jani  36.641648  10.270523
# 172222  Azaiz ben Attia  36.644510  10.269331
# 172223           Delagi  36.631954  10.166459
#
# [172224 rows x 19 columns]

# %%
RCP45.index=RCP45.date
column=['Piezometer','Pluviometer','YearlyRF','SemestrialRF','TrimestrialRF','MonthlyRF','Mean','Zone','SPI','SPI_classes','Lat','Lon','Lat_Pluviometer','Lon_Pluviometer','Month','Year']#Reindexing
RCP45=RCP45.reindex(column, axis='columns')

# %%
RCP45['YearlyRF'] = pd.to_numeric(RCP45['YearlyRF'],errors = 'coerce')
RCP45['SemestrialRF'] = pd.to_numeric(RCP45['SemestrialRF'],errors = 'coerce')
RCP45['TrimestrialRF'] = pd.to_numeric(RCP45['TrimestrialRF'],errors = 'coerce')
RCP45['MonthlyRF'] = pd.to_numeric(RCP45['MonthlyRF'],errors = 'coerce')
RCP45['Mean'] = pd.to_numeric(RCP45['Mean'],errors = 'coerce')
RCP45['Month'] = pd.to_numeric(RCP45['Month'],errors = 'coerce')
RCP45['Year'] = pd.to_numeric(RCP45['Year'],errors = 'coerce')
RCP45['SPI'] = pd.to_numeric(RCP45['SPI'],errors = 'coerce')

# %%
RCP45
# Out:
#                  Piezometer           Pluviometer    YearlyRF  SemestrialRF  \
# date
# 2009-01-01        Ben Zazia  BEN AROUS I MUNICIPA  411.898182    273.444545
# 2009-01-01             Fraj  BEN AROUS I MUNICIPA  411.898182    273.444545
# 2009-01-01       Bir El Kif  BEN AROUS I MUNICIPA  411.898182    273.444545
# 2009-01-01         El Attar  BEN AROUS I MUNICIPA  411.898182    273.444545
# 2009-01-01           Majoul  BEN AROUS I MUNICIPA  411.898182    273.444545
# ...                     ...                   ...         ...           ...
# 2100-12-01        UCP Ouzra      OUZRA AGRI FLORA  312.445465    149.702278
# 2100-12-01     Salah Khamar      OUZRA AGRI FLORA  312.445465    149.702278
# 2100-12-01    Haj Hadi Jani      OUZRA AGRI FLORA  312.445465    149.702278
# 2100-12-01  Azaiz ben Attia      OUZRA AGRI FLORA  312.445465    149.702278
# 2100-12-01           Delagi      OUZRA AGRI FLORA  312.445465    149.702278
#
#             TrimestrialRF  MonthlyRF       Mean  Zone       SPI  \
# date
# 2009-01-01     158.488182  32.339427  32.587273     4  0.034115
# 2009-01-01     158.488182  32.339427  32.587273     4  0.034115
# 2009-01-01     158.488182  32.339427  32.587273     4  0.034115
# 2009-01-01     158.488182  32.339427  32.587273     4  0.034115
# 2009-01-01     158.488182  32.339427  32.587273     4  0.034115
# ...                   ...        ...        ...   ...       ...
# 2100-12-01      97.629775  20.193310  31.990834     1 -0.000486
# 2100-12-01      97.629775  20.193310  31.990834     1 -0.000486
# 2100-12-01      97.629775  20.193310  31.990834     1 -0.000486
# 2100-12-01      97.629775  20.193310  31.990834     1 -0.000486
# 2100-12-01      97.629775  20.193310  31.990834     1 -0.000486
#
#                SPI_classes        Lat        Lon  Lat_Pluviometer  \
# date
# 2009-01-01  Moderately Wet  36.712677  10.296590         36.76500
# 2009-01-01  Moderately Wet  36.721854  10.300582         36.76500
# 2009-01-01  Moderately Wet  36.717664  10.294973         36.76500
# 2009-01-01  Moderately Wet  36.728039  10.314714         36.76500
# 2009-01-01  Moderately Wet  36.736674  10.273134         36.76500
# ...                    ...        ...        ...              ...
# 2100-12-01  Moderately dry  36.650512  10.231095         36.62639
# 2100-12-01  Moderately dry  36.653313  10.191087         36.62639
# 2100-12-01  Moderately dry  36.641648  10.270523         36.62639
# 2100-12-01  Moderately dry  36.644510  10.269331         36.62639
# 2100-12-01  Moderately dry  36.631954  10.166459         36.62639
#
#             Lon_Pluviometer  Month  Year
# date
# 2009-01-01        -10.22111      1  2009
# 2009-01-01        -10.22111      1  2009
# 2009-01-01        -10.22111      1  2009
# 2009-01-01        -10.22111      1  2009
# 2009-01-01        -10.22111      1  2009
# ...                     ...    ...   ...
# 2100-12-01        -10.25639     12  2100
# 2100-12-01        -10.25639     12  2100
# 2100-12-01        -10.25639     12  2100
# 2100-12-01        -10.25639     12  2100
# 2100-12-01        -10.25639     12  2100
#
# [172224 rows x 16 columns]

# %%
RCP45.to_pickle("./Pickles/Data/RCP45.pkl")

# %% [markdown]
# <a id="rcp85_pp"></a>
#
# ${\textbf{Representative Concentration Pathway :RCP 8.5 Preparation}}$

# %%
RCP85.rename(columns = {'date(YYYY-MM)':'date'}, inplace = True)
list_Year= [d.year for d in RCP85.date]
list_Month= [d.month for d in RCP85.date]
RCP85['Month'] = list_Month
RCP85['Year'] = list_Year

# %%
for i in RCP85.columns[RCP85.isnull().any(axis=0)]:     #---Applying Only on variables with NaN values
    RCP85[i].fillna(RCP85[i].mean(),inplace=True)#Fill NaN value by mean

# %%
RCP85Crossed=RCP85[(RCP85.Year>=2009) & (RCP85.Year<=2015)]

# %%
df=data_rain.copy()
list_Year= [d.year for d in df.Time]
list_Month= [d.month for d in df.Time]
df['Month'] = list_Month
df['Year'] = list_Year
dfCrossed=df[(df.Year>=2009) & (df.Year<=2015)]
df=dfCrossed[['Pluviometer', 'MonthlyRF', 'Year', 'Month']].copy()

# %%
rg=df['Pluviometer'].unique()
storage=list()
for i in range(0,len(rg)):
    aa=df[["MonthlyRF","Year",'Month']][(df.Pluviometer==rg[i])].groupby(["Year",'Month']).mean()
    aa.rename(columns = {'MonthlyRF':rg[i]}, inplace = True)#Renaming certain columns
    storage.append(aa)

# %%
for i in range(0,len(storage)):
    RCP85Crossed= pd.merge(RCP85Crossed,storage[i], on=['Year','Month'], how='inner')#Merging piezometric data and pluviometric data on sem and zone

# %%
RCP85Crossed.index=RCP85Crossed.date
del RCP85Crossed['date']

# %%
storageLR=list()
for i in range(13,len(RCP85Crossed.columns)):
    X = RCP85Crossed[['MIROC-ESM', 'CNRM-CM5', 'CanESM2', 'FGOALS-s2', 'BNU-ESM',
       'MIROC5', 'GFDL-ESM2G', 'MIROC-ESM-CHEM', 'GFDL-ESM2M', 'MRI-CGCM3',
       'bcc-csm1-1']].copy()
#     X = sm.add_constant(X)
    y = RCP85Crossed[[RCP85Crossed.columns[i]]]
    X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.3, random_state=42)
    est1 = sm.OLS(y_train, X_train)
    est2 = est1.fit()
    y_pred=est2.predict(X_test)
    print(RCP85Crossed.columns[i])
    print("\n")
    print(est2.summary())
    print("\n")
    RMSE=np.sqrt(mean_squared_error(y_test,y_pred))
    storageLR.append(
            {
                'RG':RCP85Crossed.columns[i],
                'RMSE':  RMSE,
                'Adj. R-squared':est2.rsquared_adj,
                'AIC':est2.aic,
                'BIC':est2.bic,
                'est':est2
            }
        )
rmseDataLR=pd.DataFrame(storageLR)
# Out:
# BEN AROUS I MUNICIPA
#
#
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     BEN AROUS I MUNICIPA   R-squared (uncentered):                   0.682
# Model:                              OLS   Adj. R-squared (uncentered):              0.608
# Method:                   Least Squares   F-statistic:                              9.179
# Date:                  Fri, 22 Jul 2022   Prob (F-statistic):                    1.78e-08
# Time:                          11:11:23   Log-Likelihood:                         -269.99
# No. Observations:                    58   AIC:                                      562.0
# Df Residuals:                        47   BIC:                                      584.6
# Df Model:                            11
# Covariance Type:              nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.2300      0.172      1.334      0.189      -0.117       0.577
# CNRM-CM5           0.0582      0.165      0.354      0.725      -0.273       0.389
# CanESM2            0.0443      0.237      0.187      0.852      -0.432       0.521
# FGOALS-s2          0.3197      0.253      1.263      0.213      -0.190       0.829
# BNU-ESM           -0.0545      0.196     -0.277      0.783      -0.450       0.341
# MIROC5            -0.2223      0.187     -1.188      0.241      -0.599       0.154
# GFDL-ESM2G         0.1578      0.190      0.832      0.410      -0.224       0.539
# MIROC-ESM-CHEM     0.1566      0.200      0.782      0.438      -0.246       0.559
# GFDL-ESM2M        -0.0079      0.255     -0.031      0.975      -0.520       0.505
# MRI-CGCM3          0.1339      0.206      0.650      0.519      -0.280       0.548
# bcc-csm1-1         0.2112      0.198      1.067      0.291      -0.187       0.610
# ==============================================================================
# Omnibus:                        4.712   Durbin-Watson:                   1.954
# Prob(Omnibus):                  0.095   Jarque-Bera (JB):                3.690
# Skew:                           0.534   Prob(JB):                        0.158
# Kurtosis:                       3.623   Cond. No.                         12.4
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# BOUMHEL BASSATINE MU
#
#
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     BOUMHEL BASSATINE MU   R-squared (uncentered):                   0.641
# Model:                              OLS   Adj. R-squared (uncentered):              0.557
# Method:                   Least Squares   F-statistic:                              7.641
# Date:                  Fri, 22 Jul 2022   Prob (F-statistic):                    2.38e-07
# Time:                          11:11:23   Log-Likelihood:                         -268.12
# No. Observations:                    58   AIC:                                      558.2
# Df Residuals:                        47   BIC:                                      580.9
# Df Model:                            11
# Covariance Type:              nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.2191      0.167      1.313      0.196      -0.117       0.555
# CNRM-CM5           0.0657      0.159      0.412      0.682      -0.255       0.386
# CanESM2            0.0459      0.229      0.200      0.842      -0.415       0.507
# FGOALS-s2          0.3643      0.245      1.486      0.144      -0.129       0.857
# BNU-ESM           -0.0602      0.190     -0.316      0.753      -0.443       0.323
# MIROC5            -0.2742      0.181     -1.513      0.137      -0.639       0.090
# GFDL-ESM2G         0.1709      0.184      0.931      0.357      -0.199       0.540
# MIROC-ESM-CHEM     0.2001      0.194      1.032      0.307      -0.190       0.590
# GFDL-ESM2M        -0.1439      0.247     -0.583      0.562      -0.640       0.352
# MRI-CGCM3          0.0498      0.199      0.250      0.804      -0.351       0.451
# bcc-csm1-1         0.2726      0.192      1.422      0.162      -0.113       0.658
# ==============================================================================
# Omnibus:                       12.813   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               15.211
# Skew:                           0.886   Prob(JB):                     0.000498
# Kurtosis:                       4.777   Cond. No.                         12.4
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# CRETEVILLE
#
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             CRETEVILLE   R-squared (uncentered):                   0.597
# Model:                            OLS   Adj. R-squared (uncentered):              0.503
# Method:                 Least Squares   F-statistic:                              6.341
# Date:                Fri, 22 Jul 2022   Prob (F-statistic):                    2.67e-06
# Time:                        11:11:23   Log-Likelihood:                         -288.23
# No. Observations:                  58   AIC:                                      598.5
# Df Residuals:                      47   BIC:                                      621.1
# Df Model:                          11
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.3741      0.236      1.585      0.120      -0.101       0.849
# CNRM-CM5          -0.0040      0.225     -0.018      0.986      -0.458       0.450
# CanESM2            0.0838      0.324      0.258      0.797      -0.569       0.736
# FGOALS-s2          0.5578      0.347      1.609      0.114      -0.140       1.255
# BNU-ESM           -0.1019      0.269     -0.379      0.707      -0.643       0.439
# MIROC5            -0.5003      0.256     -1.952      0.057      -1.016       0.015
# GFDL-ESM2G         0.1778      0.260      0.685      0.497      -0.345       0.700
# MIROC-ESM-CHEM     0.0521      0.274      0.190      0.850      -0.499       0.604
# GFDL-ESM2M        -0.0320      0.349     -0.092      0.927      -0.734       0.670
# MRI-CGCM3          0.1708      0.282      0.606      0.548      -0.396       0.738
# bcc-csm1-1         0.4359      0.271      1.607      0.115      -0.110       0.981
# ==============================================================================
# Omnibus:                       43.661   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              187.494
# Skew:                           2.013   Prob(JB):                     1.93e-41
# Kurtosis:                      10.834   Cond. No.                         12.4
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# DOMAINE DECHAMUNE
#
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:      DOMAINE DECHAMUNE   R-squared (uncentered):                   0.677
# Model:                            OLS   Adj. R-squared (uncentered):              0.602
# Method:                 Least Squares   F-statistic:                              8.968
# Date:                Fri, 22 Jul 2022   Prob (F-statistic):                    2.51e-08
# Time:                        11:11:23   Log-Likelihood:                         -272.10
# No. Observations:                  58   AIC:                                      566.2
# Df Residuals:                      47   BIC:                                      588.9
# Df Model:                          11
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.2948      0.179      1.649      0.106      -0.065       0.654
# CNRM-CM5          -0.0082      0.171     -0.048      0.962      -0.352       0.335
# CanESM2            0.0939      0.246      0.382      0.704      -0.400       0.588
# FGOALS-s2          0.3730      0.263      1.421      0.162      -0.155       0.901
# BNU-ESM           -0.0111      0.204     -0.055      0.957      -0.421       0.399
# MIROC5            -0.2418      0.194     -1.246      0.219      -0.632       0.149
# GFDL-ESM2G        -0.0156      0.197     -0.079      0.937      -0.411       0.380
# MIROC-ESM-CHEM     0.1384      0.208      0.667      0.508      -0.279       0.556
# GFDL-ESM2M         0.0571      0.264      0.216      0.830      -0.474       0.589
# MRI-CGCM3          0.0725      0.214      0.340      0.736      -0.357       0.502
# bcc-csm1-1         0.3386      0.205      1.649      0.106      -0.074       0.752
# ==============================================================================
# Omnibus:                       10.462   Durbin-Watson:                   1.868
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               12.223
# Skew:                           0.720   Prob(JB):                      0.00222
# Kurtosis:                       4.728   Cond. No.                         12.4
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# EZZAHRA
#
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                EZZAHRA   R-squared (uncentered):                   0.664
# Model:                            OLS   Adj. R-squared (uncentered):              0.586
# Method:                 Least Squares   F-statistic:                              8.458
# Date:                Fri, 22 Jul 2022   Prob (F-statistic):                    5.82e-08
# Time:                        11:11:23   Log-Likelihood:                         -260.17
# No. Observations:                  58   AIC:                                      542.3
# Df Residuals:                      47   BIC:                                      565.0
# Df Model:                          11
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.2179      0.146      1.497      0.141      -0.075       0.511
# CNRM-CM5           0.1143      0.139      0.822      0.415      -0.165       0.394
# CanESM2           -0.1625      0.200     -0.813      0.420      -0.565       0.240
# FGOALS-s2          0.3315      0.214      1.551      0.128      -0.099       0.761
# BNU-ESM            0.0302      0.166      0.182      0.856      -0.304       0.364
# MIROC5            -0.2580      0.158     -1.633      0.109      -0.576       0.060
# GFDL-ESM2G         0.1927      0.160      1.204      0.235      -0.129       0.515
# MIROC-ESM-CHEM     0.1408      0.169      0.833      0.409      -0.199       0.481
# GFDL-ESM2M        -0.1151      0.215     -0.535      0.595      -0.548       0.318
# MRI-CGCM3          0.2427      0.174      1.396      0.169      -0.107       0.592
# bcc-csm1-1         0.0413      0.167      0.247      0.806      -0.295       0.378
# ==============================================================================
# Omnibus:                       13.776   Durbin-Watson:                   1.805
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               16.297
# Skew:                           0.962   Prob(JB):                     0.000289
# Kurtosis:                       4.744   Cond. No.                         12.4
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# FOUCHANA FERME GAMOU
#
#
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     FOUCHANA FERME GAMOU   R-squared (uncentered):                   0.641
# Model:                              OLS   Adj. R-squared (uncentered):              0.557
# Method:                   Least Squares   F-statistic:                              7.638
# Date:                  Fri, 22 Jul 2022   Prob (F-statistic):                    2.39e-07
# Time:                          11:11:23   Log-Likelihood:                         -276.48
# No. Observations:                    58   AIC:                                      575.0
# Df Residuals:                        47   BIC:                                      597.6
# Df Model:                            11
# Covariance Type:              nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.2899      0.193      1.504      0.139      -0.098       0.678
# CNRM-CM5           0.0501      0.184      0.272      0.787      -0.320       0.421
# CanESM2            0.0737      0.265      0.278      0.782      -0.459       0.606
# FGOALS-s2          0.3630      0.283      1.282      0.206      -0.207       0.933
# BNU-ESM           -0.1014      0.220     -0.462      0.647      -0.544       0.341
# MIROC5            -0.2143      0.209     -1.024      0.311      -0.635       0.207
# GFDL-ESM2G         0.1601      0.212      0.755      0.454      -0.267       0.587
# MIROC-ESM-CHEM     0.1791      0.224      0.800      0.428      -0.271       0.629
# GFDL-ESM2M        -0.1474      0.285     -0.517      0.607      -0.721       0.426
# MRI-CGCM3          0.1079      0.230      0.469      0.642      -0.355       0.571
# bcc-csm1-1         0.2840      0.221      1.283      0.206      -0.161       0.729
# ==============================================================================
# Omnibus:                       14.449   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               21.050
# Skew:                           0.863   Prob(JB):                     2.69e-05
# Kurtosis:                       5.393   Cond. No.                         12.4
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# HAMMEM LIF
#
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             HAMMEM LIF   R-squared (uncentered):                   0.698
# Model:                            OLS   Adj. R-squared (uncentered):              0.628
# Method:                 Least Squares   F-statistic:                              9.893
# Date:                Fri, 22 Jul 2022   Prob (F-statistic):                    5.83e-09
# Time:                        11:11:23   Log-Likelihood:                         -255.94
# No. Observations:                  58   AIC:                                      533.9
# Df Residuals:                      47   BIC:                                      556.5
# Df Model:                          11
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.1167      0.135      0.863      0.393      -0.155       0.389
# CNRM-CM5          -0.0332      0.129     -0.257      0.799      -0.293       0.227
# CanESM2            0.1396      0.186      0.751      0.456      -0.234       0.514
# FGOALS-s2          0.0095      0.199      0.048      0.962      -0.390       0.409
# BNU-ESM            0.0101      0.154      0.065      0.948      -0.300       0.320
# MIROC5            -0.0842      0.147     -0.574      0.569      -0.380       0.211
# GFDL-ESM2G         0.1665      0.149      1.118      0.269      -0.133       0.466
# MIROC-ESM-CHEM     0.1532      0.157      0.975      0.335      -0.163       0.469
# GFDL-ESM2M         0.0590      0.200      0.295      0.769      -0.343       0.461
# MRI-CGCM3         -0.0343      0.162     -0.212      0.833      -0.359       0.291
# bcc-csm1-1         0.3183      0.155      2.049      0.046       0.006       0.631
# ==============================================================================
# Omnibus:                        5.251   Durbin-Watson:                   1.874
# Prob(Omnibus):                  0.072   Jarque-Bera (JB):                4.361
# Skew:                           0.508   Prob(JB):                        0.113
# Kurtosis:                       3.879   Cond. No.                         12.4
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# KHELIDIA CTV
#
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:           KHELIDIA CTV   R-squared (uncentered):                   0.664
# Model:                            OLS   Adj. R-squared (uncentered):              0.585
# Method:                 Least Squares   F-statistic:                              8.444
# Date:                Fri, 22 Jul 2022   Prob (F-statistic):                    5.95e-08
# Time:                        11:11:23   Log-Likelihood:                         -273.27
# No. Observations:                  58   AIC:                                      568.5
# Df Residuals:                      47   BIC:                                      591.2
# Df Model:                          11
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.2949      0.182      1.616      0.113      -0.072       0.662
# CNRM-CM5           0.0228      0.174      0.131      0.897      -0.328       0.373
# CanESM2            0.2064      0.251      0.824      0.414      -0.298       0.711
# FGOALS-s2          0.3542      0.268      1.322      0.192      -0.185       0.893
# BNU-ESM           -0.0483      0.208     -0.232      0.817      -0.467       0.370
# MIROC5            -0.2488      0.198     -1.256      0.215      -0.647       0.150
# GFDL-ESM2G         0.0213      0.201      0.106      0.916      -0.383       0.425
# MIROC-ESM-CHEM     0.1343      0.212      0.634      0.529      -0.292       0.560
# GFDL-ESM2M        -0.0338      0.270     -0.125      0.901      -0.576       0.509
# MRI-CGCM3          0.1443      0.218      0.662      0.511      -0.294       0.583
# bcc-csm1-1         0.2393      0.210      1.142      0.259      -0.182       0.661
# ==============================================================================
# Omnibus:                       11.966   Durbin-Watson:                   1.898
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               16.627
# Skew:                           0.723   Prob(JB):                     0.000245
# Kurtosis:                       5.189   Cond. No.                         12.4
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# KHELIDIA POMPAGE
#
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:       KHELIDIA POMPAGE   R-squared (uncentered):                   0.653
# Model:                            OLS   Adj. R-squared (uncentered):              0.571
# Method:                 Least Squares   F-statistic:                              8.028
# Date:                Fri, 22 Jul 2022   Prob (F-statistic):                    1.21e-07
# Time:                        11:11:23   Log-Likelihood:                         -269.87
# No. Observations:                  58   AIC:                                      561.7
# Df Residuals:                      47   BIC:                                      584.4
# Df Model:                          11
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.2501      0.172      1.454      0.153      -0.096       0.596
# CNRM-CM5           0.0114      0.164      0.070      0.945      -0.319       0.342
# CanESM2            0.0760      0.236      0.321      0.749      -0.399       0.551
# FGOALS-s2          0.3878      0.253      1.535      0.132      -0.121       0.896
# BNU-ESM           -0.1207      0.196     -0.616      0.541      -0.515       0.274
# MIROC5            -0.2704      0.187     -1.448      0.154      -0.646       0.105
# GFDL-ESM2G         0.0765      0.189      0.404      0.688      -0.304       0.457
# MIROC-ESM-CHEM     0.1940      0.200      0.971      0.337      -0.208       0.596
# GFDL-ESM2M        -0.0828      0.254     -0.326      0.746      -0.594       0.429
# MRI-CGCM3          0.1972      0.205      0.959      0.342      -0.216       0.611
# bcc-csm1-1         0.2680      0.198      1.356      0.181      -0.129       0.666
# ==============================================================================
# Omnibus:                       17.546   Durbin-Watson:                   1.954
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.322
# Skew:                           1.026   Prob(JB):                     1.17e-06
# Kurtosis:                       5.664   Cond. No.                         12.4
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# MEGRINE PARC CRDA
#
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:      MEGRINE PARC CRDA   R-squared (uncentered):                   0.703
# Model:                            OLS   Adj. R-squared (uncentered):              0.634
# Method:                 Least Squares   F-statistic:                              10.13
# Date:                Fri, 22 Jul 2022   Prob (F-statistic):                    4.05e-09
# Time:                        11:11:23   Log-Likelihood:                         -264.31
# No. Observations:                  58   AIC:                                      550.6
# Df Residuals:                      47   BIC:                                      573.3
# Df Model:                          11
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.1702      0.156      1.089      0.282      -0.144       0.485
# CNRM-CM5           0.0053      0.149      0.035      0.972      -0.295       0.306
# CanESM2            0.0211      0.215      0.098      0.922      -0.411       0.453
# FGOALS-s2          0.2227      0.230      0.970      0.337      -0.239       0.684
# BNU-ESM            0.0043      0.178      0.024      0.981      -0.354       0.363
# MIROC5            -0.1542      0.170     -0.909      0.368      -0.495       0.187
# GFDL-ESM2G         0.1796      0.172      1.044      0.302      -0.166       0.526
# MIROC-ESM-CHEM     0.1979      0.182      1.090      0.281      -0.167       0.563
# GFDL-ESM2M         0.0050      0.231      0.022      0.983      -0.460       0.470
# MRI-CGCM3          0.1195      0.187      0.640      0.525      -0.256       0.495
# bcc-csm1-1         0.1888      0.180      1.052      0.298      -0.172       0.550
# ==============================================================================
# Omnibus:                        2.969   Durbin-Watson:                   1.909
# Prob(Omnibus):                  0.227   Jarque-Bera (JB):                2.210
# Skew:                           0.462   Prob(JB):                        0.331
# Kurtosis:                       3.248   Cond. No.                         12.4
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# MHAMEDIA DISPENSAIRE
#
#
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     MHAMEDIA DISPENSAIRE   R-squared (uncentered):                   0.642
# Model:                              OLS   Adj. R-squared (uncentered):              0.558
# Method:                   Least Squares   F-statistic:                              7.663
# Date:                  Fri, 22 Jul 2022   Prob (F-statistic):                    2.29e-07
# Time:                          11:11:23   Log-Likelihood:                         -272.07
# No. Observations:                    58   AIC:                                      566.1
# Df Residuals:                        47   BIC:                                      588.8
# Df Model:                            11
# Covariance Type:              nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.2455      0.179      1.374      0.176      -0.114       0.605
# CNRM-CM5           0.0709      0.171      0.415      0.680      -0.272       0.414
# CanESM2            0.0400      0.245      0.163      0.871      -0.454       0.534
# FGOALS-s2          0.2513      0.262      0.958      0.343      -0.277       0.779
# BNU-ESM           -0.0772      0.204     -0.379      0.706      -0.487       0.333
# MIROC5            -0.1989      0.194     -1.025      0.310      -0.589       0.191
# GFDL-ESM2G         0.2008      0.197      1.021      0.312      -0.195       0.596
# MIROC-ESM-CHEM     0.1811      0.208      0.873      0.387      -0.236       0.599
# GFDL-ESM2M        -0.1157      0.264     -0.438      0.663      -0.647       0.416
# MRI-CGCM3          0.2252      0.213      1.055      0.297      -0.204       0.655
# bcc-csm1-1         0.1311      0.205      0.639      0.526      -0.282       0.544
# ==============================================================================
# Omnibus:                       15.250   Durbin-Watson:                   2.083
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.582
# Skew:                           0.907   Prob(JB):                     1.25e-05
# Kurtosis:                       5.461   Cond. No.                         12.4
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# MORNAG SIDI ZEYED
#
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:      MORNAG SIDI ZEYED   R-squared (uncentered):                   0.699
# Model:                            OLS   Adj. R-squared (uncentered):              0.629
# Method:                 Least Squares   F-statistic:                              9.925
# Date:                Fri, 22 Jul 2022   Prob (F-statistic):                    5.55e-09
# Time:                        11:11:23   Log-Likelihood:                         -271.71
# No. Observations:                  58   AIC:                                      565.4
# Df Residuals:                      47   BIC:                                      588.1
# Df Model:                          11
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.3524      0.178      1.985      0.053      -0.005       0.710
# CNRM-CM5           0.0200      0.170      0.118      0.906      -0.321       0.361
# CanESM2            0.1537      0.244      0.630      0.532      -0.337       0.644
# FGOALS-s2          0.3611      0.261      1.385      0.173      -0.164       0.886
# BNU-ESM           -0.0761      0.202     -0.376      0.709      -0.483       0.331
# MIROC5            -0.2426      0.193     -1.259      0.214      -0.630       0.145
# GFDL-ESM2G         0.0734      0.195      0.376      0.709      -0.320       0.466
# MIROC-ESM-CHEM     0.1092      0.206      0.530      0.599      -0.306       0.524
# GFDL-ESM2M        -0.0573      0.262     -0.218      0.828      -0.585       0.471
# MRI-CGCM3          0.0592      0.212      0.279      0.781      -0.367       0.486
# bcc-csm1-1         0.3762      0.204      1.845      0.071      -0.034       0.786
# ==============================================================================
# Omnibus:                       10.775   Durbin-Watson:                   1.936
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               13.201
# Skew:                           0.713   Prob(JB):                      0.00136
# Kurtosis:                       4.852   Cond. No.                         12.4
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# MORNEG CTV
#
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             MORNEG CTV   R-squared (uncentered):                   0.680
# Model:                            OLS   Adj. R-squared (uncentered):              0.605
# Method:                 Least Squares   F-statistic:                              9.079
# Date:                Fri, 22 Jul 2022   Prob (F-statistic):                    2.09e-08
# Time:                        11:11:23   Log-Likelihood:                         -275.55
# No. Observations:                  58   AIC:                                      573.1
# Df Residuals:                      47   BIC:                                      595.8
# Df Model:                          11
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.2861      0.190      1.508      0.138      -0.096       0.668
# CNRM-CM5           0.0337      0.181      0.186      0.853      -0.331       0.398
# CanESM2            0.1748      0.261      0.671      0.506      -0.349       0.699
# FGOALS-s2          0.4031      0.279      1.447      0.155      -0.157       0.964
# BNU-ESM           -0.1608      0.216     -0.743      0.461      -0.596       0.274
# MIROC5            -0.3521      0.206     -1.710      0.094      -0.766       0.062
# GFDL-ESM2G         0.2581      0.209      1.236      0.222      -0.162       0.678
# MIROC-ESM-CHEM     0.1789      0.220      0.812      0.421      -0.264       0.622
# GFDL-ESM2M        -0.0532      0.280     -0.190      0.850      -0.617       0.511
# MRI-CGCM3          0.1048      0.227      0.462      0.646      -0.351       0.561
# bcc-csm1-1         0.2748      0.218      1.261      0.213      -0.164       0.713
# ==============================================================================
# Omnibus:                        6.638   Durbin-Watson:                   1.952
# Prob(Omnibus):                  0.036   Jarque-Bera (JB):                5.726
# Skew:                           0.721   Prob(JB):                       0.0571
# Kurtosis:                       3.541   Cond. No.                         12.4
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# MORNEG FERME ESSADIR
#
#
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     MORNEG FERME ESSADIR   R-squared (uncentered):                   0.680
# Model:                              OLS   Adj. R-squared (uncentered):              0.605
# Method:                   Least Squares   F-statistic:                              9.065
# Date:                  Fri, 22 Jul 2022   Prob (F-statistic):                    2.14e-08
# Time:                          11:11:23   Log-Likelihood:                         -271.39
# No. Observations:                    58   AIC:                                      564.8
# Df Residuals:                        47   BIC:                                      587.4
# Df Model:                            11
# Covariance Type:              nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.2945      0.177      1.667      0.102      -0.061       0.650
# CNRM-CM5           0.0501      0.169      0.297      0.768      -0.289       0.389
# CanESM2            0.1897      0.243      0.782      0.438      -0.298       0.678
# FGOALS-s2          0.3120      0.259      1.203      0.235      -0.210       0.834
# BNU-ESM           -0.0996      0.201     -0.495      0.623      -0.505       0.305
# MIROC5            -0.2473      0.192     -1.290      0.203      -0.633       0.138
# GFDL-ESM2G         0.1464      0.194      0.754      0.455      -0.244       0.537
# MIROC-ESM-CHEM     0.1822      0.205      0.888      0.379      -0.230       0.595
# GFDL-ESM2M        -0.0758      0.261     -0.290      0.773      -0.601       0.449
# MRI-CGCM3          0.0817      0.211      0.387      0.700      -0.343       0.506
# bcc-csm1-1         0.2361      0.203      1.164      0.250      -0.172       0.644
# ==============================================================================
# Omnibus:                       12.722   Durbin-Watson:                   1.750
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               17.033
# Skew:                           0.797   Prob(JB):                     0.000200
# Kurtosis:                       5.123   Cond. No.                         12.4
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# OUDHNA FERME CHIBOUB
#
#
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     OUDHNA FERME CHIBOUB   R-squared (uncentered):                   0.553
# Model:                              OLS   Adj. R-squared (uncentered):              0.448
# Method:                   Least Squares   F-statistic:                              5.281
# Date:                  Fri, 22 Jul 2022   Prob (F-statistic):                    2.30e-05
# Time:                          11:11:23   Log-Likelihood:                         -274.72
# No. Observations:                    58   AIC:                                      571.4
# Df Residuals:                        47   BIC:                                      594.1
# Df Model:                            11
# Covariance Type:              nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.2557      0.187      1.367      0.178      -0.121       0.632
# CNRM-CM5           0.0731      0.179      0.409      0.684      -0.286       0.433
# CanESM2            0.3324      0.257      1.294      0.202      -0.185       0.849
# FGOALS-s2          0.2600      0.275      0.947      0.349      -0.293       0.813
# BNU-ESM           -0.1932      0.213     -0.906      0.370      -0.622       0.236
# MIROC5            -0.2621      0.203     -1.291      0.203      -0.670       0.146
# GFDL-ESM2G         0.1294      0.206      0.629      0.532      -0.285       0.543
# MIROC-ESM-CHEM     0.0838      0.217      0.386      0.701      -0.353       0.521
# GFDL-ESM2M        -0.0983      0.276     -0.356      0.724      -0.654       0.458
# MRI-CGCM3          0.0272      0.223      0.122      0.904      -0.422       0.477
# bcc-csm1-1         0.2867      0.215      1.335      0.188      -0.145       0.719
# ==============================================================================
# Omnibus:                       29.000   Durbin-Watson:                   1.958
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               63.746
# Skew:                           1.528   Prob(JB):                     1.44e-14
# Kurtosis:                       7.128   Cond. No.                         12.4
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# OUZRA AGRI FLORA
#
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:       OUZRA AGRI FLORA   R-squared (uncentered):                   0.677
# Model:                            OLS   Adj. R-squared (uncentered):              0.602
# Method:                 Least Squares   F-statistic:                              8.969
# Date:                Fri, 22 Jul 2022   Prob (F-statistic):                    2.50e-08
# Time:                        11:11:23   Log-Likelihood:                         -269.42
# No. Observations:                  58   AIC:                                      560.8
# Df Residuals:                      47   BIC:                                      583.5
# Df Model:                          11
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.3135      0.171      1.837      0.073      -0.030       0.657
# CNRM-CM5           0.0114      0.163      0.070      0.945      -0.317       0.339
# CanESM2            0.0588      0.234      0.251      0.803      -0.413       0.531
# FGOALS-s2          0.3540      0.251      1.412      0.164      -0.150       0.858
# BNU-ESM           -0.1216      0.195     -0.625      0.535      -0.513       0.270
# MIROC5            -0.1593      0.185     -0.860      0.394      -0.532       0.213
# GFDL-ESM2G         0.0388      0.188      0.207      0.837      -0.339       0.417
# MIROC-ESM-CHEM     0.0805      0.198      0.406      0.686      -0.318       0.479
# GFDL-ESM2M         0.0743      0.252      0.295      0.770      -0.433       0.582
# MRI-CGCM3          0.0953      0.204      0.468      0.642      -0.315       0.505
# bcc-csm1-1         0.2676      0.196      1.365      0.179      -0.127       0.662
# ==============================================================================
# Omnibus:                        3.246   Durbin-Watson:                   1.935
# Prob(Omnibus):                  0.197   Jarque-Bera (JB):                2.343
# Skew:                           0.448   Prob(JB):                        0.310
# Kurtosis:                       3.408   Cond. No.                         12.4
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# RADES OUAFA
#
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:            RADES OUAFA   R-squared (uncentered):                   0.779
# Model:                            OLS   Adj. R-squared (uncentered):              0.727
# Method:                 Least Squares   F-statistic:                              15.06
# Date:                Fri, 22 Jul 2022   Prob (F-statistic):                    6.25e-12
# Time:                        11:11:23   Log-Likelihood:                         -251.55
# No. Observations:                  58   AIC:                                      525.1
# Df Residuals:                      47   BIC:                                      547.8
# Df Model:                          11
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.1068      0.125      0.851      0.399      -0.146       0.359
# CNRM-CM5           0.0583      0.120      0.487      0.629      -0.183       0.299
# CanESM2           -0.0721      0.172     -0.419      0.677      -0.419       0.274
# FGOALS-s2          0.0589      0.184      0.320      0.751      -0.312       0.429
# BNU-ESM           -0.0497      0.143     -0.347      0.730      -0.337       0.238
# MIROC5            -0.2084      0.136     -1.530      0.133      -0.482       0.066
# GFDL-ESM2G         0.2567      0.138      1.860      0.069      -0.021       0.534
# MIROC-ESM-CHEM     0.0817      0.146      0.561      0.578      -0.211       0.375
# GFDL-ESM2M         0.1348      0.185      0.727      0.471      -0.238       0.508
# MRI-CGCM3          0.4280      0.150      2.857      0.006       0.127       0.729
# bcc-csm1-1         0.1344      0.144      0.933      0.355      -0.155       0.424
# ==============================================================================
# Omnibus:                        4.356   Durbin-Watson:                   1.729
# Prob(Omnibus):                  0.113   Jarque-Bera (JB):                3.565
# Skew:                           0.400   Prob(JB):                        0.168
# Kurtosis:                       3.914   Cond. No.                         12.4
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# RADES PF
#
#
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               RADES PF   R-squared (uncentered):                   0.624
# Model:                            OLS   Adj. R-squared (uncentered):              0.536
# Method:                 Least Squares   F-statistic:                              7.086
# Date:                Fri, 22 Jul 2022   Prob (F-statistic):                    6.50e-07
# Time:                        11:11:23   Log-Likelihood:                         -265.10
# No. Observations:                  58   AIC:                                      552.2
# Df Residuals:                      47   BIC:                                      574.9
# Df Model:                          11
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# MIROC-ESM          0.2042      0.158      1.289      0.204      -0.115       0.523
# CNRM-CM5          -0.0323      0.151     -0.213      0.832      -0.337       0.272
# CanESM2            0.0993      0.218      0.456      0.650      -0.338       0.537
# FGOALS-s2          0.1659      0.233      0.713      0.479      -0.302       0.634
# BNU-ESM           -0.0436      0.181     -0.242      0.810      -0.407       0.320
# MIROC5            -0.1668      0.172     -0.970      0.337      -0.513       0.179
# GFDL-ESM2G         0.1247      0.174      0.715      0.478      -0.226       0.475
# MIROC-ESM-CHEM     0.1034      0.184      0.562      0.577      -0.267       0.474
# GFDL-ESM2M         0.0525      0.234      0.224      0.824      -0.419       0.523
# MRI-CGCM3          0.1436      0.189      0.759      0.452      -0.237       0.524
# bcc-csm1-1         0.1941      0.182      1.067      0.292      -0.172       0.560
# ==============================================================================
# Omnibus:                       28.884   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               64.826
# Skew:                           1.506   Prob(JB):                     8.38e-15
# Kurtosis:                       7.213   Cond. No.                         12.4
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
rmseDataLR[["RG","RMSE","Adj. R-squared","AIC","BIC"]].sort_values(by=['Adj. R-squared'],ascending=False).head(1)
# Out:
#              RG      RMSE  Adj. R-squared        AIC         BIC
# 16  RADES OUAFA  25.23996          0.7272  525.09565  547.760523

# %%
storage1V1=list()
for i in range(13,len(RCP85Crossed.columns)):
    for j in range(0,10):
        RMSE=np.sqrt(mean_squared_error(RCP85Crossed[RCP85Crossed.columns[i]],RCP85Crossed[RCP85Crossed.columns[j]]))
        storage1V1.append(
            {
                'RG':RCP85Crossed.columns[i],
                'MODEL':RCP85Crossed.columns[j],
                'RMSE':  RMSE,

            }
        )
rmseData1V1=pd.DataFrame(storage1V1)

# %%
rmseData1V1.groupby(['MODEL']).min(['RMSE'])
# Out:
#                      RMSE
# MODEL
# BNU-ESM         30.683696
# CNRM-CM5        32.115369
# CanESM2         30.879476
# FGOALS-s2       31.107356
# GFDL-ESM2G      31.310951
# GFDL-ESM2M      31.864867
# MIROC-ESM       29.557271
# MIROC-ESM-CHEM  29.556554
# MIROC5          37.418253
# MRI-CGCM3       28.021086

# %%
RCP85.index=RCP85.date
date=RCP85['date']
del RCP85['date']

# %%
RCP85["MonthlyRF"]=0.0
est=rmseDataLR["est"][16]
for i in range(0,len(est.params)):
    RCP85["MonthlyRF"]+=est.params[i]*RCP85[RCP85.columns[i]]
RCP85["MonthlyRF"][RCP85["MonthlyRF"]<0.0]=0.0

# %%
RCP85["Mean"] = RCP85.loc[:, ['MIROC-ESM', 'CNRM-CM5', 'CanESM2', 'FGOALS-s2', 'BNU-ESM',
       'MIROC5', 'GFDL-ESM2G', 'MIROC-ESM-CHEM', 'GFDL-ESM2M', 'MRI-CGCM3',
       'bcc-csm1-1']].mean(axis = 1)
RCP85.to_pickle("./Pickles/Data/RCP85Complete.pkl")
RCP85=RCP85[['Month','Year','MonthlyRF','Mean']].copy()
RCP85['date']=date

# %%
RCP85['sem']= RCP85.date.dt.year.astype(str) + 'S'+ np.where(RCP85.date.dt.quarter.gt(2),2,1).astype(str)
RCP85['trim']= RCP85.date.dt.year.astype(str) + 'T'+ RCP85.date.dt.quarter.astype(str)

# %%
SPI=(RCP85['Mean']-RCP85['Mean'].mean())/RCP85['Mean'].std()#SPI Calculation 
RCP85['SPI']=SPI#Creating a new column for the SPI

# %%
RCP85['SPI_classes']=""#Creating a new column for the interpretation of the spi
for i in range(0,len(RCP85)):
    if(RCP85['SPI'].values[i]>2):#SPI>2
        RCP85['SPI_classes'].values[i]="Extremely wet"
    elif((RCP85['SPI'].values[i]< 2) & (RCP85['SPI'].values[i] >1)):#1<SPI< 2
        RCP85['SPI_classes'].values[i]="Very wet"
    elif((RCP85['SPI'].values[i]< 1) & (RCP85['SPI'].values[i] >0)):#0<SPI< 1
        RCP85['SPI_classes'].values[i]="Moderately Wet"
    elif((RCP85['SPI'].values[i] >-1 )&( RCP85['SPI'].values[i] <0)):#-1<SPI< 0
        RCP85['SPI_classes'].values[i]="Moderately dry"
    elif((RCP85['SPI'].values[i] >-2 )&( RCP85['SPI'].values[i] <-1)):#-2<SPI<-1
        RCP85['SPI_classes'].values[i]="Severely dry"
    else :#SPI< -2
        RCP85['SPI_classes'].values[i]="Extremely dry"

# %%
dfSem=RCP85.copy()
dfSem=dfSem.groupby(['sem',]).sum('Mean')#Summing Rainfall on Pluviometer and Semester
dfSem.drop(columns=['Month','Year','MonthlyRF','SPI'],axis=1,inplace=True)#Droping the unuseful columns
dfSem.rename(columns = {'Mean':'SemestrialRF'}, inplace = True)#Renaming P to MonthlyP for more clarity

# %%
dfTrim=RCP85.copy()
dfTrim=dfTrim.groupby(['trim']).sum('Mean')#Summing Rainfall on Pluviometer and Trimestre
dfTrim.drop(columns=['Month','Year','SPI','MonthlyRF'],axis=1,inplace=True)#Droping the unuseful columns
dfTrim.rename(columns = {'Mean':'TrimestrialRF'}, inplace = True)#Renaming RF to TrimestrialRF for more clarity

# %%
dfyear=RCP85.copy()
dfyear=dfyear.groupby(['Year']).sum('Mean')#Summing Rainfall on Pluviometer and Trimestre
dfyear.drop(columns=['Month','SPI','MonthlyRF'],axis=1,inplace=True)#Droping the unuseful columns
dfyear.rename(columns = {'Mean':'YearlyRF'}, inplace = True)#Renaming RF to TrimestrialRF for more clarity

# %%
RCP85 = pd.merge(RCP85,dfyear, on=['Year'], how='inner')#Merging the zone with the pluviometric data on Rain Gauge
RCP85 = pd.merge(RCP85,dfSem, on=['sem'], how='inner')#Merging the zone with the pluviometric data on Rain Gauge
RCP85 = pd.merge(RCP85,dfTrim, on=['trim'], how='inner')#Merging the zone with the pluviometric data on Rain Gauge

# %%
df1 = pd.DataFrame({'Pluviometer' : data_rain["Pluviometer"].unique()})

# %%
RCP85 = pd.DataFrame(np.repeat(RCP85.values, 18, axis=0), columns=RCP85.columns)
df1=df1.append([df1] * 1104, ignore_index=True)

# %%
RCP85=RCP85.join(df1)
RCP85.index=RCP85.date

# %%
data_rain1=data_rain[['Pluviometer','Lat_Pluviometer','Lon_Pluviometer','Zone']].copy()
data_rain1.drop_duplicates(keep="first",inplace=True)
RCP85= pd.merge(RCP85,data_rain1,on=['Pluviometer'], how='inner')#Merging piezometric data and pluviometric data on sem and zone

# %%
data_piezo1=data_piezo[["Piezometer",'Lat','Lon','Zone']]
data_piezo1.drop_duplicates(keep="first",inplace=True)
RCP85= pd.merge(RCP85,data_piezo1,on=['Zone'], how='inner')#Merging piezometric data and pluviometric data on sem and zone

# %%
RCP85.index=RCP85.date
column=['Piezometer','Pluviometer','YearlyRF','SemestrialRF','TrimestrialRF','MonthlyRF','Mean','Zone','SPI','SPI_classes','Lat','Lon','Lat_Pluviometer','Lon_Pluviometer','Month','Year']#Reindexing
RCP85=RCP85.reindex(column, axis='columns')

# %%
RCP85['YearlyRF'] = pd.to_numeric(RCP85['YearlyRF'],errors = 'coerce')
RCP85['SemestrialRF'] = pd.to_numeric(RCP85['SemestrialRF'],errors = 'coerce')
RCP85['TrimestrialRF'] = pd.to_numeric(RCP85['TrimestrialRF'],errors = 'coerce')
RCP85['MonthlyRF'] = pd.to_numeric(RCP85['MonthlyRF'],errors = 'coerce')
RCP85['Mean'] = pd.to_numeric(RCP85['Mean'],errors = 'coerce')
RCP85['Month'] = pd.to_numeric(RCP85['Month'],errors = 'coerce')
RCP85['Year'] = pd.to_numeric(RCP85['Year'],errors = 'coerce')
RCP85['SPI'] = pd.to_numeric(RCP85['SPI'],errors = 'coerce')

# %%
RCP85
# Out:
#                  Piezometer           Pluviometer    YearlyRF  SemestrialRF  \
# date
# 2009-01-01        Ben Zazia  BEN AROUS I MUNICIPA  354.381818    216.021818
# 2009-01-01             Fraj  BEN AROUS I MUNICIPA  354.381818    216.021818
# 2009-01-01       Bir El Kif  BEN AROUS I MUNICIPA  354.381818    216.021818
# 2009-01-01         El Attar  BEN AROUS I MUNICIPA  354.381818    216.021818
# 2009-01-01           Majoul  BEN AROUS I MUNICIPA  354.381818    216.021818
# ...                     ...                   ...         ...           ...
# 2100-12-01        UCP Ouzra      OUZRA AGRI FLORA  287.226304    132.698606
# 2100-12-01     Salah Khamar      OUZRA AGRI FLORA  287.226304    132.698606
# 2100-12-01    Haj Hadi Jani      OUZRA AGRI FLORA  287.226304    132.698606
# 2100-12-01  Azaiz ben Attia      OUZRA AGRI FLORA  287.226304    132.698606
# 2100-12-01           Delagi      OUZRA AGRI FLORA  287.226304    132.698606
#
#             TrimestrialRF  MonthlyRF       Mean  Zone       SPI  \
# date
# 2009-01-01     134.808182   7.612261  28.776364     4 -0.117682
# 2009-01-01     134.808182   7.612261  28.776364     4 -0.117682
# 2009-01-01     134.808182   7.612261  28.776364     4 -0.117682
# 2009-01-01     134.808182   7.612261  28.776364     4 -0.117682
# 2009-01-01     134.808182   7.612261  28.776364     4 -0.117682
# ...                   ...        ...        ...   ...       ...
# 2100-12-01      84.353849   9.675063  27.523707     1 -0.192284
# 2100-12-01      84.353849   9.675063  27.523707     1 -0.192284
# 2100-12-01      84.353849   9.675063  27.523707     1 -0.192284
# 2100-12-01      84.353849   9.675063  27.523707     1 -0.192284
# 2100-12-01      84.353849   9.675063  27.523707     1 -0.192284
#
#                SPI_classes        Lat        Lon  Lat_Pluviometer  \
# date
# 2009-01-01  Moderately dry  36.712677  10.296590         36.76500
# 2009-01-01  Moderately dry  36.721854  10.300582         36.76500
# 2009-01-01  Moderately dry  36.717664  10.294973         36.76500
# 2009-01-01  Moderately dry  36.728039  10.314714         36.76500
# 2009-01-01  Moderately dry  36.736674  10.273134         36.76500
# ...                    ...        ...        ...              ...
# 2100-12-01  Moderately dry  36.650512  10.231095         36.62639
# 2100-12-01  Moderately dry  36.653313  10.191087         36.62639
# 2100-12-01  Moderately dry  36.641648  10.270523         36.62639
# 2100-12-01  Moderately dry  36.644510  10.269331         36.62639
# 2100-12-01  Moderately dry  36.631954  10.166459         36.62639
#
#             Lon_Pluviometer  Month  Year
# date
# 2009-01-01        -10.22111      1  2009
# 2009-01-01        -10.22111      1  2009
# 2009-01-01        -10.22111      1  2009
# 2009-01-01        -10.22111      1  2009
# 2009-01-01        -10.22111      1  2009
# ...                     ...    ...   ...
# 2100-12-01        -10.25639     12  2100
# 2100-12-01        -10.25639     12  2100
# 2100-12-01        -10.25639     12  2100
# 2100-12-01        -10.25639     12  2100
# 2100-12-01        -10.25639     12  2100
#
# [172224 rows x 16 columns]

# %%
RCP85.to_pickle("./Pickles/Data/RCP85.pkl")
