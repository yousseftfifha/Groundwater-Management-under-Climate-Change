# %% [markdown]
# # <center>${\textbf{Artificial Intelligence Decision Support System}}$<br>${\textbf{ for Groundwater Management under Climate Change:}}$</center><br><center>${\textbf{ Application to Mornag Region in Tunisia}}$</center><br><center>${\textbf{Part 4 : Deployment Using LSTM}}$</center>

# %% [markdown]
# **Table of Contents**
# * [Importing Libraries](#libraris)
# * [Forecasting under Climate Change scenarios](#cc)
#     * [Representative Concentration Pathway :RCP 4.5](#rcp4.5_1)
#     * [Representative Concentration Pathway :RCP 8.5](#rcp8.5_1)
# * [Analysis](#Analysis)

# %% [markdown]
# <a id="libraries"></a>
#
# ${\textbf{Importing Libraries}}$

# %%
# %matplotlib inline
import warnings
warnings.simplefilter("ignore")

import numpy as np
import pandas as pd

from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

import tensorflow as tf

import pickle

import seaborn as sns
import plotly.graph_objects as go
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
Historical_Data = pd.read_pickle('./Pickles/Data/Historical_Data.pkl')
LSTM = tf.keras.models.load_model('./Pickles/Models/my_modelLSTM.h5')

# %%
from tensorflow.keras.utils import plot_model

# %%
dot_img_file = '/tmp/model_1.png'
plot_model(LSTM, to_file=dot_img_file, show_shapes=True)

# %% [markdown]
# <a id="cc"></a>
#
# ## ${\textbf{LSTM Forecasting under Climate Change scenarios}}$

# %%
def createXY(dataset,n_past):
    dataX = []
    dataY = []
    for i in range(n_past, len(dataset)):
            dataX.append(dataset[i - n_past:i, 0:dataset.shape[1]])
            dataY.append(dataset[i,0])
    return np.array(dataX),np.array(dataY)

# %% [markdown]
# <a id="rcp4.5_1"></a>
#
# >${\textbf{Representative Concentration Pathway :RCP 4.5 }}$

# %%
RCP45 = pd.read_pickle('./Pickles/Data/RCP45.pkl')
del RCP45['MonthlyRF']
RCP45.rename(columns = {'Mean':'MonthlyRF'}, inplace = True)#Renaming Zone_num to zone for more clarity

# %%
RCP45['MonthlyRF'].max()
# Out:
# 99.7909090909091

# %%
del RCP45['Lat']
del RCP45['Lon']
del RCP45['Lat_Pluviometer']
del RCP45['Lon_Pluviometer']

# %%
lb_make = LabelEncoder()
RCP45["Piezometer"] = lb_make.fit_transform(RCP45["Piezometer"])
lb_make1 = LabelEncoder()
RCP45["Pluviometer"] = lb_make1.fit_transform(RCP45["Pluviometer"])
lb_make2 = LabelEncoder()
RCP45["SPI_classes"] = lb_make2.fit_transform(RCP45["SPI_classes"])
RCP45['Pz']=0

# %%
scaler = MinMaxScaler(feature_range=(0,1))
RCP45_scaled = scaler.fit_transform(RCP45)

# %%
X,Y=createXY(RCP45_scaled,30)

# %%
prediction=LSTM.predict(X)
prediction_copies_array = np.repeat(prediction,12, axis=-1)
pred=scaler.inverse_transform(np.reshape(prediction_copies_array,(len(prediction),12)))[:,0]

RCP45["Piezometer"] = lb_make.inverse_transform(RCP45["Piezometer"])
RCP45["Pluviometer"] = lb_make1.inverse_transform(RCP45["Pluviometer"])
RCP45["SPI_classes"] = lb_make2.inverse_transform(RCP45["SPI_classes"])
RCP45=RCP45[30:]
RCP45["Pz"]=pred
# Out:
# 5382/5382 [==============================] - 16s 3ms/step

# %%
RCP45
# Out:
#                  Piezometer           Pluviometer    YearlyRF  SemestrialRF  \
# date
# 2009-06-01        Ben Zazia  BEN AROUS I MUNICIPA  411.898182    273.444545
# 2009-06-01             Fraj  BEN AROUS I MUNICIPA  411.898182    273.444545
# 2009-06-01       Bir El Kif  BEN AROUS I MUNICIPA  411.898182    273.444545
# 2009-06-01         El Attar  BEN AROUS I MUNICIPA  411.898182    273.444545
# 2009-06-01           Majoul  BEN AROUS I MUNICIPA  411.898182    273.444545
# ...                     ...                   ...         ...           ...
# 2100-12-01        UCP Ouzra      OUZRA AGRI FLORA  278.813636    132.886364
# 2100-12-01     Salah Khamar      OUZRA AGRI FLORA  278.813636    132.886364
# 2100-12-01    Haj Hadi Jani      OUZRA AGRI FLORA  278.813636    132.886364
# 2100-12-01  Azaiz ben Attia      OUZRA AGRI FLORA  278.813636    132.886364
# 2100-12-01           Delagi      OUZRA AGRI FLORA  278.813636    132.886364
#
#             TrimestrialRF  MonthlyRF  Zone       SPI     SPI_classes  Month  \
# date
# 2009-06-01     114.956364  50.622727     4  1.081351        Very wet      6
# 2009-06-01     114.956364  50.622727     4  1.081351        Very wet      6
# 2009-06-01     114.956364  50.622727     4  1.081351        Very wet      6
# 2009-06-01     114.956364  50.622727     4  1.081351        Very wet      6
# 2009-06-01     114.956364  50.622727     4  1.081351        Very wet      6
# ...                   ...        ...   ...       ...             ...    ...
# 2100-12-01      89.221818  29.188182     1 -0.161186  Moderately dry     12
# 2100-12-01      89.221818  29.188182     1 -0.161186  Moderately dry     12
# 2100-12-01      89.221818  29.188182     1 -0.161186  Moderately dry     12
# 2100-12-01      89.221818  29.188182     1 -0.161186  Moderately dry     12
# 2100-12-01      89.221818  29.188182     1 -0.161186  Moderately dry     12
#
#             Year         Pz
# date
# 2009-06-01  2009  32.227219
# 2009-06-01  2009   9.997550
# 2009-06-01  2009  14.223544
# 2009-06-01  2009  10.789429
# 2009-06-01  2009  13.514144
# ...          ...        ...
# 2100-12-01  2100  12.824013
# 2100-12-01  2100  37.395370
# 2100-12-01  2100  35.531178
# 2100-12-01  2100  13.712179
# 2100-12-01  2100   3.296118
#
# [172194 rows x 12 columns]

# %% [markdown]
# <a id="rcp8.5_1"></a>
#
# >${\textbf{Representative Concentration Pathway :RCP 8.5 }}$

# %%
RCP85 = pd.read_pickle('./Pickles/Data/RCP85.pkl')
del RCP85['MonthlyRF']
RCP85.rename(columns = {'Mean':'MonthlyRF'}, inplace = True)#Renaming Zone_num to zone for more clarity

# %%
del RCP85['Lat']
del RCP85['Lon']
del RCP85['Lat_Pluviometer']
del RCP85['Lon_Pluviometer']

# %%
lb_make = LabelEncoder()
RCP85["Piezometer"] = lb_make.fit_transform(RCP85["Piezometer"])
lb_make1 = LabelEncoder()
RCP85["Pluviometer"] = lb_make1.fit_transform(RCP85["Pluviometer"])
lb_make2 = LabelEncoder()
RCP85["SPI_classes"] = lb_make2.fit_transform(RCP85["SPI_classes"])
RCP85['Pz']=0

# %%
scaler = MinMaxScaler(feature_range=(0,1))
RCP85_scaled = scaler.fit_transform(RCP85)

# %%
X,Y=createXY(RCP85_scaled,30)

# %%
prediction=LSTM.predict(X)
prediction_copies_array = np.repeat(prediction,12, axis=-1)
pred=scaler.inverse_transform(np.reshape(prediction_copies_array,(len(prediction),12)))[:,0]

RCP85["Piezometer"] = lb_make.inverse_transform(RCP85["Piezometer"])
RCP85["Pluviometer"] = lb_make1.inverse_transform(RCP85["Pluviometer"])
RCP85["SPI_classes"] = lb_make2.inverse_transform(RCP85["SPI_classes"])
RCP85=RCP85[30:]
RCP85["Pz"]=pred
# Out:
# 5382/5382 [==============================] - 14s 3ms/step

# %%
RCP85[RCP85.Piezometer=='UCP Ennajah_484']
# Out:
#                  Piezometer           Pluviometer    YearlyRF  SemestrialRF  \
# date
# 2009-01-01  UCP Ennajah_484  FOUCHANA FERME GAMOU  354.381818    216.021818
# 2009-02-01  UCP Ennajah_484  FOUCHANA FERME GAMOU  354.381818    216.021818
# 2009-03-01  UCP Ennajah_484  FOUCHANA FERME GAMOU  354.381818    216.021818
# 2009-04-01  UCP Ennajah_484  FOUCHANA FERME GAMOU  354.381818    216.021818
# 2009-05-01  UCP Ennajah_484  FOUCHANA FERME GAMOU  354.381818    216.021818
# ...                     ...                   ...         ...           ...
# 2100-08-01  UCP Ennajah_484  MORNEG FERME ESSADIR  222.970909    100.570909
# 2100-09-01  UCP Ennajah_484  MORNEG FERME ESSADIR  222.970909    100.570909
# 2100-10-01  UCP Ennajah_484  MORNEG FERME ESSADIR  222.970909    100.570909
# 2100-11-01  UCP Ennajah_484  MORNEG FERME ESSADIR  222.970909    100.570909
# 2100-12-01  UCP Ennajah_484  MORNEG FERME ESSADIR  222.970909    100.570909
#
#             TrimestrialRF  MonthlyRF  Zone       SPI     SPI_classes  Month  \
# date
# 2009-01-01     134.808182  28.776364     3 -0.113993  Moderately dry      1
# 2009-02-01     134.808182  42.771818     3  0.717884  Moderately Wet      2
# 2009-03-01     134.808182  63.260000     3  1.935683        Very wet      3
# 2009-04-01      81.213636  18.864545     3 -0.703142  Moderately dry      4
# 2009-05-01      81.213636  30.001818     3 -0.041153  Moderately dry      5
# ...                   ...        ...   ...       ...             ...    ...
# 2100-08-01      32.280909  11.743636     3 -1.126402    Severely dry      8
# 2100-09-01      32.280909  14.476364     3 -0.963971  Moderately dry      9
# 2100-10-01      68.290000  20.682727     3 -0.595071  Moderately dry     10
# 2100-11-01      68.290000  25.438182     3 -0.312411  Moderately dry     11
# 2100-12-01      68.290000  22.169091     3 -0.506723  Moderately dry     12
#
#             Year         Pz
# date
# 2009-01-01  2009  19.168800
# 2009-02-01  2009  18.619127
# 2009-03-01  2009  18.706564
# 2009-04-01  2009  18.696020
# 2009-05-01  2009  18.404980
# ...          ...        ...
# 2100-08-01  2100  16.752684
# 2100-09-01  2100  16.403021
# 2100-10-01  2100  16.289635
# 2100-11-01  2100  16.101482
# 2100-12-01  2100  15.965505
#
# [2208 rows x 12 columns]

# %% [markdown]
# <a id="Analysis"></a>
#
# ${\textbf{Analysis }}$

# %%
list_nom = RCP85.Piezometer.unique()
list_nom=['UCP Ennajah_484']
# plt.rcParams['font.size'] = '16'
for d in list_nom:
    df=RCP85[(RCP85.Piezometer==d) &(RCP85.Pluviometer=="FOUCHANA FERME GAMOU")& (RCP85.Month==9)]
    df1=RCP45[(RCP45.Piezometer==d)& (RCP45.Pluviometer=="FOUCHANA FERME GAMOU")&(RCP85.Month==9)]

    print(d)
    df=df.reset_index()
    df.index=df.date
    plt.figure(figsize=(12,5))

    ax1 = df.groupby(['Month','Year'])['Pz'].mean().plot(color='blue', grid=True, label='Piezomtric level impaced by RCP 8.5')
    ax2 = df1.groupby(['Month','Year'])['Pz'].mean().plot(color='green', grid=True, secondary_y=True, label='Piezomtric level impaced by RCP 4.5')

    h1, l1 = ax1.get_legend_handles_labels()
    h2, l2 = ax2.get_legend_handles_labels()



    plt.legend(h1+h2, l1+l2, loc=2)
    plt.show()
# Out:
# UCP Ennajah_484
